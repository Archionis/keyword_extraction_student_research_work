# %%
from datasets import load_dataset
import nltk
from tqdm import tqdm
import re
import spacy
from spacy.tokenizer import _get_regex_pattern
# Out:
# c:\Users\Maxim Zubarev\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# Импортирование датасета INCPEC с hugging face

# %%
from datasets import load_dataset
import datasets
#!!!this dataset can be imported only with datasets library version < 4.0.0!!!
print (datasets.__version__)

# load the inspec dataset
dataset = load_dataset('taln-ls2n/inspec')
# Out:
# 2.16.0
# Using the latest cached version of the module from C:\Users\Maxim Zubarev\.cache\huggingface\modules\datasets_modules\datasets\taln-ls2n--inspec\0ae146cabe770846946b3279b4c751efe0aca2dd68b3f24427d4624cd22bb20d (last modified on Thu Dec 11 16:48:11 2025) since it couldn't be found locally at taln-ls2n/inspec, or remotely on the Hugging Face Hub.

# %% [markdown]
# Соединение частей датасетов в один

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
val_dataset = dataset['validation']

# %%
full_dataset = datasets.concatenate_datasets([train_dataset, test_dataset, val_dataset])

# %% [markdown]
# Импортирование и редактирование языковой модели под слова с дефисами

# %%
nlp = spacy.load("en_core_web_sm")
re_token_match = _get_regex_pattern(nlp.Defaults.token_match)
re_token_match = f"({re_token_match}|\w+-\w+)"
nlp.tokenizer.token_match = re.compile(re_token_match).match
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Maxim Zubarev\AppData\Local\Temp\ipykernel_3992\2674231081.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re_token_match = f"({re_token_match}|\w+-\w+)"

# %% [markdown]
# Обработка данных: приведение заголовка и введения в один текст, стеммизация ключевых слов

# %%
def preprocessing(dataset, nlp):
    keyphrases = []
    text = []
    for sample in tqdm(dataset):
        sample_keyphrases = []
        text.append(sample["title"] + ". " + sample["abstract"])
        for keyphrase in sample["keyphrases"]:
            tokens = [token.text for token in nlp(keyphrase)]
            stemmed = [nltk.stem.snowball.SnowballStemmer('porter').stem(token.lower()) for token in tokens]
            sample_keyphrases.append(" ".join(stemmed))
        keyphrases.append(sample_keyphrases)
    return text, keyphrases

# %%
text, references = preprocessing(full_dataset, nlp)
# Out:
# 100%|██████████| 2000/2000 [01:53<00:00, 17.58it/s]

# %% [markdown]
# Извлечение слов. Максимальная длина n-грама 3. KeyBERT использует пользовательский векторизатор, учитывающий грамматическую связь слов

# %%
def extraction(model, text, references, stemmer, vectorizer=None):
    output = []
    for doc, reference in tqdm(zip(text, references)):
        n = len(reference)
        match model.__class__.__name__:
            case 'KeyBERT':
                keywords = model.extract_keywords(
                    doc,
                    keyphrase_ngram_range=(1, 3),
                    vectorizer=vectorizer,
                    use_mmr=True,
                    diversity=0.7,
                    top_n=n * 2)
                stemmed = []
                for kw, score in keywords:
                    words = kw.split()
                    stemmed_words = [stemmer.stem(word.lower()) for word in words]
                    stemmed_phrase = " ".join(stemmed_words)    
                    stemmed.append(stemmed_phrase)
                output.append(stemmed[:n])
            case 'Rake':
                model.extract_keywords_from_text(doc)
                keywords = model.get_ranked_phrases()
                stemmed = []
                for kw in keywords:
                    words = kw.split()
                    stemmed_words = [stemmer.stem(word.lower()) for word in words]
                    stemmed_phrase = " ".join(stemmed_words)    
                    stemmed.append(stemmed_phrase)
                output.append(stemmed[:n])
            case _:
                model.load_document(input=doc)
                model.grammar_selection(grammar="NP: {<ADJ>*<NOUN|PROPN>+}")
                model.candidate_weighting()
                output.append([keyword for keyword, rank in model.get_n_best(n=n, stemming=True)])
    return output

# %%
from pke.unsupervised import TextRank, TopicRank, YAKE
from CustomVectorizer import CustomVectorizer
from nltk.corpus import stopwords
from keybert import KeyBERT
from rake_nltk import Rake
nltk.download('stopwords')
nltk.download('punkt')
stemmer = stemmer = nltk.stem.snowball.SnowballStemmer('porter')
nlp = spacy.load("en_core_web_sm")
vectorizer = CustomVectorizer(
    nlp_model=nlp,
    ngram_range=(1, 3),
    stop_words='english')
outputs = {}
for model in [KeyBERT, Rake, TextRank, TopicRank, YAKE]:
    extractor = model()
    if extractor.__class__.__name__ == 'Rake':
        extractor = model(stopwords=stopwords.words('english'), language='english', max_length=3)
    outputs[extractor.__class__.__name__] = extraction(extractor, text, references, stemmer, vectorizer=vectorizer)
outputs
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Maxim
# [nltk_data]     Zubarev\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Maxim
# [nltk_data]     Zubarev\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2000it [04:16,  7.78it/s]
# 2000it [00:02, 686.58it/s]
# 2000it [24:26,  1.36it/s]
# 2000it [24:08,  1.38it/s]
# 2000it [24:29,  1.36it/s]
# {'KeyBERT': [['lattic ga algorithm',
#    'nmr techniqu',
#    'qubit quantum inform',
#    'puls techniqu',
#    'densiti',
#    'processor',
#    'ideal simul',
#    'reson'],
#   ['sma fund', 'small bank', 'outsourc', 'account', 'servic', 'invest'],
#   ['diagnost system',
#    'multipl simultan failur',
#    'complex industri applic',
#    'design cycl',
#    'modular'],
#   ['particular minimum cliqu',
#    'graph invari',
#    'induc odd cycl',
#    'stabl set',
#    'special structur',
#    'cardin'],
#   ['packetvideo',
#    'stream wireless market',
#    'content provid',
#    'semiconductor vendor',
#    'pictur expert group',
#    'encod',
#    'technolog',
#    'handheld wireless termin'],
#   ['arbitrari quantum dynam',
#    'univers quantum comput',
#    'composit quantum system',
#    'univers simul',
#    'dimension state space',
#    'hamiltonian',
#    'qudit',
#    'compon system',
#    'local unitari',
#    'd dimens',
#    'interact',
#    'state'],
#   ['dynam vibrat absorb',
#    'optim criterion',
#    'element type dva',
#    'power spectrum',
#    'primari system'],
#   ['stochast game',
#    'discount rate',
#    '- algebra set',
#    'polynomi converg rate',
#    'asymptot properti',
#    'max valu',
#    'nondiscount',
#    'payoff'],
#   ['rf field',
#    'rf field behavior',
#    'field quadratur coil',
#    'rf field polar',
#    'quadratur coil design',
#    'field quadratur',
#    'coil design',
#    'field intens',
#    'rf',
#    'surfac coil',
#    'quadratur surfac',
#    'coil',
#    'mhz',
#    'high field',
#    'human head',
#    'quadratur',
#    'polar',
#    'recept',
#    'imag intens distribut',
#    'field behavior'],
#   ['inform retriev thesauru',
#    'thesauru',
#    'famili plan term',
#    'famili plan disciplin',
#    'plan term',
#    'retriev',
#    'term',
#    'classif',
#    'cd',
#    'inform',
#    'socio',
#    'guidelin',
#    'isi softwar',
#    'famili'],
#   ['scada system',
#    'hous personnel',
#    'more control',
#    'program',
#    'specif',
#    'new technolog'],
#   ['enterpris server releas', 'activ directori', 'net', 'slow progress'],
#   ['scale secur multicast',
#    'server approach',
#    'data encrypt',
#    'forward secreci',
#    'key tree',
#    'data stream',
#    'larg user',
#    'total bandwidth',
#    'user pool',
#    'messag',
#    'low overhead',
#    'multipl group',
#    'join',
#    'internet',
#    'simpl dynam scheme',
#    'overal system'],
#   ['player quantum game',
#    'cooper three-',
#    'entangl',
#    'player',
#    'initi state',
#    '- zero sum'],
#   ['weblog', 'law firm', 'valuabl content', 'searchabl archiv'],
#   ['model identif methodolog',
#    'accur blackbox model',
#    'evolutionari comput',
#    'local parametr tune',
#    'differenti perform',
#    'excel fit perform',
#    'physic system'],
#   ['gener control paramet',
#    'genet approach',
#    'integr control',
#    'frequenc transient',
#    'power system chang',
#    'power line',
#    'global optimum valu',
#    'continu load',
#    'control',
#    'frequenc bia factor'],
#   ['busi softwar',
#    'right vendor',
#    'right softwar',
#    'vendor hype',
#    'relationship'],
#   ['workflow manag',
#    '- agent collabor',
#    'commerc process',
#    'busi rule',
#    'b2b',
#    'monitor',
#    'procur',
#    'process chang',
#    'applic environ',
#    'transact risk'],
#   ['enterpris resourc plan',
#    'erp',
#    'applic softwar',
#    'web',
#    'process',
#    'nervou system'],
#   ['equip analysi execut',
#    'gi',
#    'geograph inform system',
#    'prevent mainten',
#    'reliabl',
#    'srp',
#    'load point',
#    'benefit model',
#    'priorit',
#    'river project',
#    'facil',
#    'asset manag initi',
#    'analysi type influenc',
#    'wood pole',
#    'critic circuit'],
#   ['fmri signal',
#    'mri',
#    'physiolog motion artifact',
#    'navig echo',
#    'hippocampu',
#    'imag distort',
#    'suffici tempor resolut',
#    'shot epi acquisit',
#    'sever suscept artifact',
#    'multiseg',
#    'signal dropout',
#    'blood oxygen level',
#    'background gradient',
#    'readout'],
#   ['schur polynomi',
#    'complex schur polynomi',
#    'real polynomi',
#    'polynomi',
#    'phase condit',
#    'tchebyshev represent',
#    'real coeffici',
#    'phase',
#    'other fundament bound'],
#   ['point wavelet',
#    'multiresolut',
#    'compress',
#    'subdivis scheme',
#    'spline',
#    'numer analysi',
#    'synthesi algorithm',
#    'linear time complex',
#    'function',
#    'point',
#    'physic simul'],
#   ['radiotherapi plan',
#    'singl fraction radiosurgeri',
#    'mlc leaf size',
#    'moder dose rang',
#    'treatment deliveri',
#    'cn tumor',
#    'millennium multileaf',
#    'varian medic system',
#    'dynam mlc treatment',
#    'smaller beamlet',
#    'collim',
#    'dose conform',
#    'target volum',
#    'neck',
#    'helio',
#    'squamou cell',
#    'window techniqu',
#    'imrt',
#    'cadplan'],
#   ['flexibl manufactur system',
#    'product capac',
#    'product ratio',
#    'maximum product rate',
#    'manufactur',
#    'differ part type',
#    'iter procedur',
#    'pallet',
#    'capac',
#    'ratio',
#    'singl paramet',
#    'simul',
#    'build'],
#   ['ventil data',
#    'perfus ratio',
#    'arteri spin',
#    'left lung',
#    'invers',
#    'signal intens',
#    'spin label',
#    'averag v',
#    'mri',
#    'oxygen',
#    'q techniqu',
#    'ms+or-112',
#    'averag t',
#    'normal distribut',
#    'inert ga elimin',
#    'ioniz radiat',
#    'si',
#    'flow'],
#   ['laser measur',
#    'profil measur system',
#    'floor plan',
#    'major window manufactur',
#    'accuraci',
#    'custom softwar',
#    '- section area',
#    'meter',
#    'intern profil',
#    'cost estim',
#    'frame',
#    'distanc',
#    'shape'],
#   ['model predict control',
#    'quadrat program',
#    'effici qp algorithm',
#    'complement algorithm',
#    'direct control problem',
#    'constraint handl',
#    'larg mpc',
#    'c++',
#    'paper machin',
#    'qpschur',
#    'detail simul',
#    'addit featur'],
#   ['al qaeda', 'network', 'war game', 'danger'],
#   ['law report', 'bane', 'transcript', 'invalu percept'],
#   ['financialcont',
#    'individu web site',
#    'corpor news report',
#    'market chart',
#    'individu investor'],
#   ['fcc chairman', 'regul', 'senat', 'michael powel'],
#   ['male comput scienc',
#    'colleg choic',
#    'women student',
#    'attract option',
#    'open letter',
#    'young woman'],
#   ['robust stabil analysi',
#    'dc convert',
#    'linear fraction transform',
#    'regul',
#    'mode dc',
#    'basic switch',
#    'buck',
#    'uncertainti',
#    'capacit c',
#    'boost',
#    'nomin model',
#    'o/(1 + delta',
#    'mu -tool',
#    'model',
#    'control'],
#   ['indiscern relat',
#    'modal logic',
#    'complementar relat',
#    'relat type',
#    'inform system',
#    'character',
#    'relat',
#    'inform'],
#   ['gener bipartit tournament',
#    'vertex set',
#    'feedback vertex',
#    'vertex incid matrix',
#    'cycl pack problem',
#    'vertex',
#    'polynomi time algorithm',
#    'tournament',
#    'cover cycl',
#    'max theorem',
#    'max relat',
#    'cycl',
#    'linear system',
#    'cover',
#    'set problem',
#    'theorem'],
#   ['econom cut condit',
#    'determinist optim approach',
#    'maximum product',
#    'constraint',
#    'oper',
#    'singl pass',
#    'numer studi',
#    'speed domain',
#    'cam softwar'],
#   ['edg lamin tool',
#    'tool geometri',
#    'benchmark part shape',
#    'profil segment',
#    'iter tool',
#    'awj cutter',
#    'trajectori algorithm',
#    'abras water jet'],
#   ['content manag',
#    'process manag softwar',
#    'manag softwar',
#    'busi process',
#    'manag',
#    'softwar'],
#   ['crm', 'custom relationship', 'big busi', 'manufactur', 'softwar'],
#   ['safeguard tax servic',
#    'failov server',
#    'time backup',
#    'supplier neverfail',
#    'protect'],
#   ['petri net',
#    'recurs parallel program',
#    '- agent system',
#    'model task plan',
#    'decid',
#    'dynam object',
#    'token',
#    'applic'],
#   ['blood vessel segment',
#    'adapt imag enhanc',
#    'vessel imag',
#    'retin blood',
#    'better segment',
#    'priori illumin',
#    'imag system'],
#   ['collabor inform space',
#    'collect use inform',
#    'knowledg databas',
#    'inform system',
#    'busi structur',
#    'individu knowledg',
#    'inform',
#    'effect search',
#    'hierarch composit',
#    'busi process step',
#    'effici alloc',
#    'user interfac'],
#   ['boost graph librari',
#    'program approach.graph',
#    'bgl',
#    'graph term',
#    'geometri',
#    'graphic',
#    'appropri boost',
#    'first algorithm',
#    'data structur',
#    'librari',
#    'gener program'],
#   ['numer csp solv',
#    'filter techniqu',
#    'constraint satisfact',
#    'algorithm',
#    'propag queue',
#    'solv method',
#    'numer regular',
#    'interv',
#    'search',
#    'problem'],
#   ['virtual develop center',
#    'comput technolog',
#    'develop',
#    'commun group',
#    'women',
#    'institut',
#    'center'],
#   ['access need',
#    'access matter',
#    'access web',
#    'disabl',
#    'ada legisl',
#    'braill',
#    'tti access',
#    'web site'],
#   ['manufactur technolog use',
#    'uk manufactur',
#    'higher labour product',
#    'similar industri',
#    'innov',
#    'more uk',
#    'foreign direct invest',
#    'notabl differ',
#    'competit advantag',
#    'japanes practic',
#    'econom data'],
#   ['inform act',
#    'legal deposit act',
#    'govern print',
#    'new constitut',
#    'such access',
#    'publish',
#    'public depositori',
#    'south africa',
#    'variou initi',
#    'provis',
#    'servic',
#    'public bodi',
#    'freedom'],
#   ['wireless local area', 'radio transmitt', 'wire'],
#   ['atom caviti coupl',
#    'entangl spin',
#    'optic caviti',
#    'strong coupl regim',
#    'atom',
#    'bichromat light',
#    'sup 2//',
#    'excit',
#    'bad caviti',
#    'light',
#    'gamma >',
#    'decay rate'],
#   ['chest radiograph narr',
#    'pneumothorax code',
#    'clinic inform',
#    'natur languag',
#    'pleural effus',
#    'narr',
#    'manual financi code',
#    'report',
#    'languag processor',
#    'medic center',
#    'extern valid'],
#   ['risk prefer',
#    'subconsci prime',
#    'attitud',
#    'judgment',
#    'preconsci process',
#    'decis make',
#    'delib mental oper',
#    'primaci hypothesi',
#    'infer'],
#   ['multipl robot trajectori',
#    'hebbian learn',
#    'synapt weight',
#    'neuron',
#    'encod sequenc state',
#    'complex spatiotempor sequenc',
#    'robot',
#    'learn',
#    'neural network',
#    'tempor featur',
#    'track',
#    'hebbian intralay',
#    'competit interlay',
#    'retriev abil',
#    'self',
#    'storag',
#    'process'],
#   ['spatial normal',
#    'specif brain area',
#    'brain architectur',
#    'affin registr',
#    'featur similar',
#    'global brain',
#    'schizophrenia',
#    'registr method',
#    'featur',
#    'local region',
#    'coordin system',
#    'transform',
#    'detect',
#    'affin',
#    'gray nuclei',
#    'mutual inform'],
#   ['digit stochast realiz',
#    'complex analog control',
#    'digit signal processor',
#    'stochast logic',
#    'digit implement',
#    'nonlinear dissip control',
#    'tradit digit signal',
#    'programm devic',
#    'random puls stream',
#    'analog',
#    'boolean algebra',
#    'seri reson convert',
#    'binari puls sequenc',
#    'convert',
#    'practic realiz',
#    'statist algebra',
#    'averag puls rate',
#    'implement'],
#   ['multistag product system',
#    'system perform measur',
#    'throughput rate',
#    'process time',
#    'batch size',
#    'transport',
#    'util',
#    'averag wait',
#    'push',
#    'demand variat',
#    'transport consider',
#    'metamodel approach'],
#   ['legal inform profession',
#    'inform studi cours',
#    'classif skill',
#    'law',
#    'inform',
#    'catalogu'],
#   ['mode algorithm analog',
#    'digit convert',
#    'typic convert',
#    'cmo technolog',
#    'adc',
#    'current mirror oper',
#    'resolut',
#    'analog',
#    'proper circuit techniqu',
#    'systemat error',
#    'mode',
#    'm',
#    '0.35-'],
#   ['multiphas chemistri system',
#    'cloud drop',
#    'differ droplet class',
#    'approxim matrix factor',
#    'model equat',
#    'bdf method',
#    'spars form',
#    'decomposit',
#    'oper split',
#    'phase',
#    'code lsode',
#    'linear algebra level',
#    'fast dissoci',
#    'backward reaction'],
#   ['reson control',
#    'multimod reson',
#    'q reson circuit',
#    'multipl reson mode',
#    'smart structur',
#    'reson',
#    'actuat',
#    'multimod',
#    'frequenc',
#    'feedback',
#    'circuit'],
#   ['public busi librari',
#    'inform servic',
#    'sheffield univers',
#    'compani inform',
#    'british standard inform',
#    'technic librari',
#    'leed',
#    'internet access',
#    'mainstream busi',
#    'partnership',
#    'patent inform',
#    'market research',
#    'scientif journal',
#    'network',
#    'introduct',
#    'steel compani',
#    'technolog',
#    'revolutionari impact',
#    'histori',
#    'futur opportun',
#    'articl',
#    'budget',
#    'resourc'],
#   ['process pioneer', 'agil busi', 'busi process', 'autom'],
#   ['independ speaker verif',
#    'speaker recognit evalu',
#    'nist speaker recognit',
#    'text independ speaker',
#    'utter level score',
#    'speaker covari',
#    'utter sampl',
#    'gaussian mixtur model',
#    'recognit evalu',
#    'verif accuraci',
#    'speaker',
#    'differ distort measur',
#    'level score',
#    'text',
#    'nist',
#    'sampl covari'],
#   ['clinic acceler target',
#    'carlo calcul',
#    'clinic electron',
#    'photon spectra',
#    'photon transport',
#    'similar photon energi',
#    'differ electron',
#    'realist target materi',
#    'boltzmann equat',
#    'execut time',
#    'rel energi',
#    'determinist method',
#    'beam',
#    'sun workstat'],
#   ['technic protect',
#    'open sourc',
#    'attack',
#    'prudent manag decis',
#    'limit',
#    'programm'],
#   ['ventricular capacit',
#    'diastol relax',
#    'ventricular relax',
#    'cardiac output',
#    'diastol function(',
#    'cardiovascular system',
#    'ventricl failur',
#    'heart rate',
#    'physiolog',
#    'simul',
#    'heart',
#    'stroke volum',
#    'equival electron circuit',
#    'pressur'],
#   ['fact control',
#    'convert topolog',
#    'voltag control',
#    'power invert',
#    'activ power transfer',
#    'interlin power flow',
#    'flexibl ac',
#    'static compens',
#    'unifi power',
#    'capacitor size',
#    'link voltag',
#    'flow control',
#    'transmiss system',
#    'multipuls'],
#   ['group schedul heurist',
#    'simplest labour schedul',
#    'schedul polici',
#    'product plan',
#    'manufactur cell',
#    'task',
#    'constraint',
#    'labour',
#    'manag',
#    'effici',
#    'util'],
#   ['integr boundari condit',
#    'nonloc boundari condit',
#    'heat equat',
#    'discret paramet',
#    'numer solut',
#    'discret numer process',
#    'finit differ',
#    'sectori resolv',
#    'semidiscret problem',
#    'uncondit stabil',
#    'heat',
#    'method',
#    'finit'],
#   ['santera system', 'big carrier', 'strategi overhaul', 'rboc'],
#   ['cmp model',
#    'chemic mechan polish',
#    'fundament model',
#    'process develop',
#    'semiconductor industri'],
#   ['audit practic',
#    'concern judgment',
#    'senior auditor',
#    'ultim judgment',
#    'recenc',
#    'bia',
#    'diminish reput',
#    'debia',
#    'review',
#    'report choic',
#    'procedur',
#    'legal liabil',
#    'profession set',
#    'staff',
#    'document'],
#   ['intellig takeoff control',
#    'scalabl neurofuzzi control',
#    'robot',
#    'stride',
#    'joint leg',
#    'movabl link',
#    'scalabl',
#    'difficult control',
#    'size'],
#   ['perceptu audio code',
#    'predict lossless',
#    'tradit audio',
#    'adapt linear filter',
#    'high compress ratio',
#    'low encod',
#    'lower delay',
#    'coder',
#    'music',
#    'same subband',
#    'sourc signal',
#    'listen test',
#    'reduct',
#    'independ function unit',
#    'redund',
#    'decomposit',
#    'differ sampl rate',
#    'mono',
#    'wclm',
#    'linear'],
#   ['rotat cordic algorithm',
#    'latenc rotat algorithm',
#    'rotat digit comput',
#    'rotat oper',
#    'vector rotat',
#    'vlsi circuit',
#    'quantiz approach',
#    'cordic famili',
#    'signal process applic',
#    'angl',
#    'precis perform',
#    'implement',
#    'digit comput',
#    'mani digit signal',
#    'convent coordin',
#    'latenc',
#    'cost'],
#   ['discontinu hamiltonian',
#    'determinist control problem',
#    'homogen problem',
#    'sup infin',
#    'period micro -',
#    'viscos solut techniqu',
#    'variat',
#    'averag',
#    'compact set'],
#   ['edg flap actuat',
#    'activ rotorcraft vibrat',
#    'actuat tube',
#    'shear piezoelectr tube',
#    'hing amplif devic',
#    'hing moment',
#    'unwant helicopt',
#    'simpl lever',
#    'blade trail',
#    'spring',
#    'deflect',
#    'inerti load',
#    'control system',
#    'inch',
#    'design analysi',
#    'rotat'],
#   ['na parallel benchmark', 'hpf compil', 'fortran', 'hitachi', 'execut time'],
#   ['object petri net',
#    'model protocol',
#    'net formal',
#    'token object',
#    'join structur',
#    'dynam modif',
#    'fork'],
#   ['effici lap transform',
#    'robust quantis',
#    'imag',
#    'code',
#    'transform',
#    'classif method',
#    'joint sourc'],
#   ['electropneumat system',
#    'nonlinear control law',
#    'veloc track',
#    'process design',
#    'multivari type',
#    'flat theori',
#    'specif',
#    'field',
#    'energi consumpt',
#    'system'],
#   ['semidefinit feasibl problem',
#    'new cut plane',
#    'semidefinit matrix gamma',
#    'approxim analyt center',
#    'bound convex bodi',
#    'cone',
#    'iter increas',
#    'case complex',
#    'oper research',
#    'maximum radiu',
#    'oracl'],
#   ['tool condit monitor',
#    'tool condit',
#    'tool wear',
#    'drill',
#    'failur monitor',
#    'diagnost tool',
#    'tool',
#    'current measur',
#    'cut process',
#    'wavelet transform',
#    'test materi',
#    'indirect monitor',
#    'statist paramet',
#    'analysi',
#    'vibrat'],
#   ['side arc weld',
#    'keyhol dsaw system',
#    'deep narrow penetr',
#    'laser',
#    'squar butt joint',
#    'inch',
#    'singl pass'],
#   ['sbc commun', 'regulatori complianc effort', 'term goal'],
#   ['process capabl indic',
#    'pmk/. mani process',
#    'preset capabl',
#    'requir',
#    'side specif limit',
#    'index c',
#    'test hypothesi',
#    'valu',
#    'procedur',
#    'mapl comput program',
#    'numer measur'],
#   ['upgrad practic', 'new kit', 'hardwar', 'softwar', 'resel', 'block'],
#   ['manufactur control strategi',
#    'dynam job rout',
#    'product system',
#    'altern control strategi',
#    'tighter schedul',
#    'reactiv agent',
#    'event simul model',
#    'control system',
#    'altern manufactur',
#    'agent',
#    'alloc strategi',
#    'benchmark system',
#    'hybrid strategi',
#    'heurist',
#    'contract net',
#    'floor',
#    'shop'],
#   ['swing compon local',
#    'translat program',
#    'interfac languag',
#    'gui librari',
#    'customiz framework',
#    'swing',
#    'travel dictionari',
#    'dissimilar tongu'],
#   ['web talk', 'web technolog', 'web', 'potenti custom', 'technolog'],
#   ['deblur method',
#    'wavelet packet basi',
#    'imag blur',
#    'total variat',
#    'convolut',
#    'imag',
#    'packet',
#    'oper'],
#   ['carnegi mellon',
#    'comput scienc',
#    'women',
#    'student',
#    'undergradu program',
#    'comput',
#    'clubhous',
#    'program'],
#   ['effici cellular automata',
#    'cost serial implement',
#    'restrict comput',
#    'gf(2',
#    'smart card',
#    'differ secur'],
#   ['automat attack construct',
#    'protocol',
#    'yao',
#    'dynam procedur',
#    'data subterm',
#    'asynchron composit',
#    'structur',
#    'valid accept term',
#    'new method',
#    'strand space model'],
#   ['deliver dose distribut',
#    'iter imrt optim',
#    'reduc dose',
#    'beam deliveri devic',
#    'leaf collim leaf',
#    'radiat',
#    'treatment deliveri',
#    'individu beamlet',
#    'object function',
#    'nondeliver optim result',
#    'mlc restrict',
#    'intens',
#    'dose',
#    'sequenc',
#    'function paramet',
#    'convers'],
#   ['stochast vehicl travel',
#    'nearest vehicl select',
#    'flexibl manufactur system',
#    'variou dispatch rule',
#    'longest idl vehicl',
#    'agv',
#    'empti travel time',
#    'materi handl',
#    'time'],
#   ['phobia fear',
#    'vr treatment',
#    'imagin exposur therapi',
#    'fli',
#    'efficaci',
#    'physiolog feedback',
#    'questionnair',
#    'vrgetno',
#    'behavior',
#    'diagnosi',
#    'differ'],
#   ['nonlinear chaotic system',
#    'steer trajectori',
#    'global invari set',
#    'orbit',
#    'stabil',
#    'mode control',
#    'chua'],
#   ['knowledg flow manag',
#    'tradit team softwar',
#    'knowledg share',
#    'knowledg grid',
#    'develop team',
#    'softwar develop process',
#    'team member',
#    'cognit cooper',
#    'workflow process',
#    'grid platform'],
#   ['neural network markup',
#    'xml',
#    'network model descript',
#    'data dictionari',
#    'train',
#    'output interpret',
#    'languag'],
#   ['taiwan power',
#    'computer develop plan',
#    'facil manag',
#    'tcdo',
#    'evalu process',
#    'develop effort',
#    'am/ fm',
#    'map'],
#   ['ray coher',
#    'surfac intersect',
#    'parametr surfac',
#    'primari ray',
#    'stabl ray',
#    'obstruct detect techniqu',
#    'bezier clip substitut',
#    'clip',
#    'stabl algorithm',
#    'iter',
#    'detect'],
#   ['mr angiographi',
#    'imag volum',
#    'isotrop resolut',
#    'undersampl 3d',
#    'exact contrast time',
#    '3d project trajectori',
#    'space sampl',
#    'mra',
#    'entir pulmonari vasculatur',
#    'reconstruct',
#    'interpol',
#    'fov',
#    'breath',
#    'artifact'],
#   ['connect age',
#    'onlin connect',
#    'inform age',
#    'collabor softwar',
#    'groov',
#    'network',
#    'technolog',
#    'busi',
#    'relationship',
#    'inform'],
#   ['calpoint', 'telecom', 'monthli check'],
#   ['comput',
#    'american woman',
#    'ethnic',
#    'color',
#    'higher educ',
#    'number',
#    'uniqu issu'],
#   ['linear relax system',
#    'uniqu lyapunov function',
#    'passiv dynam system',
#    'output dynam system',
#    'storag function',
#    'fade memori',
#    'dissip inequ',
#    'thermodynam potenti',
#    'passiv condit',
#    'nonlinear time',
#    'viscoelast materi',
#    'invari input',
#    'automat control',
#    'nonequilibrium',
#    'function'],
#   ['rydberg wave packet',
#    'atom data',
#    'quantum search',
#    'phase retriev process',
#    'wave packet regist',
#    'state inform retriev',
#    'energi eigenst',
#    'search protocol',
#    'constitu orbit',
#    'retriev process',
#    'coher control',
#    'puls',
#    'initi wave',
#    'protocol'],
#   ['feedback stochast control',
#    'stochast differenti equat',
#    'averag approach',
#    'random excit',
#    'respons amplitud process',
#    'nonlinear system',
#    'rayleigh approxim',
#    'ito',
#    'moment equat'],
#   ['women', 'particip', 'most countri', 'undergradu level', 'cultur factor'],
#   ['quantum full adder', 'nuclear spin', 'chain', 'reson effect'],
#   ['web servic', 'financ technolog'],
#   ['support logist system',
#    'xml',
#    'autom',
#    'busi process',
#    'descript framework',
#    'part distributor',
#    'extens markup languag',
#    'agent',
#    'seamless commun',
#    'inform model'],
#   ['abelian branch cover',
#    'branch point',
#    'finit abelian group',
#    'zq)-action',
#    'sphere',
#    'weak equival class'],
#   ['special entangl state',
#    'densiti matric',
#    'quantum comput',
#    'nonextens entropi criterion',
#    'mani spin',
#    'uniti matrix',
#    'separ',
#    'werner',
#    'critic point x',
#    'state',
#    'sup n/ uniti',
#    'charg conjug',
#    'rho =',
#    '2s',
#    'partial transposit method',
#    'cryptographi',
#    'evalu'],
#   ['e - file', 'ecf', 'case file system', 'state court', 'administr offic'],
#   ['robot excav',
#    'time delay control',
#    'hydraul actuat',
#    'control',
#    'speed level',
#    'line motion',
#    'surfac',
#    'pd - type',
#    'skill oper'],
#   ['discret chaotic process',
#    'optim estim',
#    'finit sampl',
#    'algorithm',
#    'singl valu'],
#   ['boundari valu problem',
#    'continu discret method',
#    'bound oper',
#    'side bound',
#    'method',
#    'roth'],
#   ['knowledg manag'],
#   ['truss topolog',
#    'genet algorithm',
#    'stochast search procedur',
#    'methodolog',
#    'triangl',
#    'numer exampl'],
#   ['taxonomi softwar',
#    'corpor portal',
#    'manag',
#    'effect knowledg discoveri',
#    'technolog',
#    'success content',
#    'user experi'],
#   ['spectrum crunch', 'depart plan', 'wireless carrier', 'commerc'],
#   ['comput scienc career', 'garnett foundat', 'pipelin', 'adolesc children'],
#   ['passiv damp',
#    'viscoelast layer',
#    'vibrat',
#    'element model',
#    'activ system',
#    'sever acld model',
#    'hugh',
#    'layer',
#    'time domain',
#    'mctavish method',
#    'control gain',
#    'loop finit'],
#   ['tupl consist recognit',
#    'dataset',
#    'tupl',
#    'granular',
#    'histogram',
#    'knowledg discoveri',
#    'algorithm',
#    'inconsist',
#    'tcrm',
#    'knowledg',
#    'recognit model',
#    'remark result',
#    'process time'],
#   ['- fuzzi thesauru',
#    'similar case retriev',
#    'similar mean',
#    'retriev system',
#    'test similar case',
#    'compar analysi',
#    'index valu',
#    'thesauri',
#    'measur',
#    'auto'],
#   ['oropharyng carcinoma',
#    'radiotherapi plan',
#    'gross tumor volum',
#    'imag fusion',
#    'magnet reson imag',
#    'upper neck area',
#    'fdg uptak',
#    'accur diagnosi',
#    'head',
#    'ct',
#    'clinic present',
#    'gtv volum'],
#   ['organ synthesi',
#    'dibromoalkan monophosphoryl',
#    'special experiment design',
#    'optimum condit',
#    'uncontrol factor',
#    'data analysi techniqu',
#    'yield',
#    'reaction'],
#   ['repeat sequenc databas',
#    'central databas system',
#    'genom',
#    'rsdb',
#    'data distribut',
#    'drsdb',
#    'queri'],
#   ['keyword confid estim',
#    'speech recognit system',
#    'languag model',
#    'syllabl re',
#    'rel confid measur',
#    'variou speech',
#    'markov model',
#    'accuraci',
#    'vocabulari',
#    'acoust layer',
#    'recognit',
#    'zfa',
#    'estim',
#    'posterior measur',
#    'fals alarm'],
#   ['helic comput tomographi',
#    'imag reconstruct strategi',
#    'maximum intens project',
#    'interpol approach',
#    'zebra artifact',
#    'scan geometri',
#    'contrast object detect',
#    'ct rel',
#    'reconstruct',
#    'nois ratio',
#    'parallel rebin',
#    'volum'],
#   ['channel assign scheme',
#    'import sampl',
#    'block',
#    'approxim tractabl model',
#    'mobil commun',
#    'stationari state distribut',
#    'cell capac',
#    'advanc simul',
#    'traffic load',
#    'real channel',
#    'cpu time',
#    'occup',
#    'network',
#    'meaning estim',
#    'realist size system',
#    'comput difficulti',
#    'static issc',
#    'assign',
#    'varianc estim',
#    'clock'],
#   ['fast invers algorithm',
#    'array resist',
#    'neural network simul',
#    'time invers',
#    'galvan array tool',
#    'format resist',
#    'd invers',
#    'forward solut',
#    'convent numer',
#    'array',
#    'approxim inform',
#    'superposit',
#    'layer effect',
#    'dimension reduct',
#    'unfocus data'],
#   ['imag reconstruct',
#    'composit structur',
#    'back project',
#    'simul specimen',
#    'attenu field',
#    'convolut',
#    'cross - section',
#    'cbp algorithm',
#    'numer result',
#    'filter',
#    'engin applic'],
#   ['stochast optim',
#    'differ optim method',
#    'acoust respons',
#    'vibrat',
#    'gradient',
#    'close cylind',
#    'experiment comparison',
#    'object',
#    'emiss'],
#   ['counterfactu paradox',
#    'entangl',
#    'quantum mechan',
#    'hardi',
#    'experi',
#    'surpris outcom',
#    'statement',
#    'real measur'],
#   ['strateg innov', 'law firm', 'initi', 'improv', 'firm', 'skill'],
#   ['knowledg manag',
#    'authorit knowledg base',
#    'emerg medic assist',
#    'disast situat',
#    'current humanitarian assist',
#    'multipl inform',
#    'inform technolog',
#    'use relief',
#    'decis make',
#    'differ organ',
#    'dr oper',
#    'support',
#    'resourc'],
#   ['differenti game',
#    'game similar matrix',
#    'linear reason strategi',
#    'payoff switch',
#    'fuzzi matric',
#    'player',
#    'infer rule',
#    'behavior',
#    'gsm',
#    'idea'],
#   ['stabl integr',
#    'implicit rung',
#    'gaussian method',
#    'kutta',
#    'discret',
#    'multipl shoot',
#    'ode',
#    'algebra equat'],
#   ['light control',
#    'direct current',
#    'edison',
#    'resist dimmer',
#    'typic incandesc',
#    'appar light output',
#    'midtown manhattan',
#    'dc',
#    'distribut system',
#    'theater',
#    'thoma',
#    'power',
#    'rheostat'],
#   ['quantum mechan comput',
#    'feynman',
#    'famou american physicist',
#    'mani particl'],
#   ['firmwar system sargon',
#    'monitor',
#    'updat',
#    'power industri',
#    'oper',
#    'avtomatika',
#    'instal',
#    'station'],
#   ['hypermedia system',
#    'process inform',
#    'product support',
#    'mainten',
#    'floor user',
#    'manufactur cell'],
#   ['person card', 'line purchas', 'present', 'quick deliveri', 'advantag'],
#   ['quantum mechan retrodict',
#    'photon quantum state',
#    'choic entangl',
#    'fock state',
#    'inform protocol',
#    'optic method',
#    'experiment realiz',
#    'singlet',
#    'state',
#    'vacuum',
#    'electromagnet field',
#    'choic'],
#   ['binari logic gate',
#    'digit addit',
#    'addit algorithm',
#    'binari bit',
#    'addit step',
#    'flag digit',
#    'input msd digit',
#    'optic shadow',
#    'parallel comput',
#    'comput',
#    'bit',
#    'order pair',
#    'algorithm'],
#   ['speech enhanc',
#    'nois robust speech',
#    'noisi speech spectrum',
#    'robust speech recognit',
#    'addit nois',
#    'speech spectrum',
#    'enhanc algorithm',
#    'record speech signal',
#    'clean speech',
#    'actual nois sourc',
#    'mixtur model',
#    'nois',
#    'altern speech',
#    'new algorithm',
#    'improv perform',
#    'time spectrum',
#    'spectral domain',
#    'dual codebook scheme',
#    'recognit'],
#   ['fraction delay allpass',
#    'variabl allpass filter',
#    'filter',
#    'squar method',
#    'weight equat error',
#    'delay',
#    'quadrat form',
#    'nonlinear phase',
#    'polynomi',
#    'simultan equat'],
#   ['defer correct scheme',
#    'second order boundari',
#    'nystrom method',
#    'numer solut',
#    'taylor seri',
#    'order converg',
#    'kutta'],
#   ['rheolog damper',
#    'structur nonlinear model',
#    'mrd model approach',
#    'paramet narx',
#    'identif method',
#    'magneto',
#    'simul error',
#    'valid test',
#    'methodolog'],
#   ['suffix tree',
#    'simpler merg algorithm',
#    'string',
#    'index data',
#    'farach',
#    'structur',
#    'first search',
#    'odd posit'],
#   ['telecommun infrastructur',
#    'radianz',
#    'savvi',
#    'provid',
#    'extranet',
#    'scandal',
#    'servic',
#    'bank',
#    'invest'],
#   ['spatial index',
#    'tree structur',
#    'effici r',
#    'convent dynam algorithm',
#    'extend object',
#    'minimum mutual overlay',
#    'k part',
#    'base'],
#   ['concurr haskel',
#    'perform web',
#    'prototyp web server',
#    'server',
#    'program languag',
#    'o throughput',
#    'naiv implement',
#    'toler'],
#   ['comput cerebellar',
#    'robot dynam',
#    'control',
#    'model',
#    'cell',
#    'infant state'],
#   ['satellit phone servic'],
#   ['voltag drive', 'reliabl', 'motor', 'modul'],
#   ['chromat diffus',
#    'color evolut',
#    'color space',
#    'color imag',
#    'diffus',
#    'differ color channel',
#    'rgb',
#    'spatial diffus term',
#    'oppon color',
#    'differ color',
#    'spatio',
#    'irrevers transform',
#    'thermodynam',
#    'diffus term',
#    'transform'],
#   ['internet traffic stream',
#    'user bandwidth consumpt',
#    'stream size',
#    'internet link',
#    'cach mechan',
#    'packet',
#    'isp',
#    'router',
#    'tortois',
#    'dragonfli',
#    'lifetim',
#    'byte volum',
#    'second',
#    'consumpt',
#    'flow',
#    'mice',
#    'differ site'],
#   ['quantum estim',
#    'deriv fisher inform',
#    'bogoljubov fisher inform',
#    'quantum analogu',
#    'estim',
#    'larg deviat',
#    'inform'],
#   ['ambul transport',
#    'comfort transport',
#    'postur',
#    'ambul',
#    'motion sick',
#    'ride qualiti',
#    'convent stretcher',
#    'convent transport',
#    'head acceler result',
#    'subject evalu',
#    'rapid acceler',
#    'ride',
#    'seat',
#    'assist driver',
#    'transport',
#    'motion',
#    'qualiti evalu',
#    'worst transport',
#    'semant differenti',
#    'vibrat',
#    'deceler',
#    'neg foot',
#    'driver',
#    'patient'],
#   ['c++ commun',
#    'incompat',
#    'more compat',
#    'mythic c',
#    'develop',
#    'classic c.',
#    'languag'],
#   ['bluetooth', 'commun strategi', 'firm', 'year'],
#   ['small busi suit', 'oracl', 'var interest', 'cost web'],
#   ['women comput scientist',
#    'support commun',
#    'faculti member',
#    'program',
#    'institut',
#    'benefit',
#    'network'],
#   ['erp system implement',
#    'enterpris',
#    'innov process',
#    'erp',
#    'canadian govern organ',
#    'theori framework',
#    'resourc plan',
#    'chang',
#    'tani',
#    'best practic',
#    'adopt'],
#   ['network societi',
#    'internet activ',
#    'internet',
#    'internet develop',
#    'itali',
#    'mainstream media',
#    'european averag',
#    'internet hostcount',
#    'net',
#    'media control',
#    'european union',
#    'countri',
#    'central control',
#    'societi',
#    'popul',
#    'democrat institut',
#    'averag',
#    'trend',
#    'restrict',
#    'regulatori decis'],
#   ['schedul polici',
#    'queue system',
#    'homogen random walk',
#    'certain gener prioriti',
#    'algorithm character',
#    'first undecid result',
#    'stabil',
#    'common polici',
#    'system',
#    'character'],
#   ['marbl cut',
#    'differ cut condit',
#    'frame saw process',
#    'singl diamond segment',
#    'point cut',
#    'brittl materi indent',
#    'fractur chip',
#    'blade',
#    'kinemat behaviour',
#    'domin remov process',
#    'tool',
#    'stroke chang'],
#   ['advanc encrypt standard',
#    'strong cryptographi',
#    'ae',
#    'unintellig cipher',
#    'new standard',
#    'inform age',
#    'electron mean',
#    'requir',
#    'implement'],
#   ['hpf compil',
#    'parallel perform',
#    'vender implement',
#    'particl code',
#    'fortran',
#    'portabl program',
#    '3d fluid'],
#   ['reflect judgment',
#    'ontolog',
#    'classic philosoph sens',
#    'stimuli',
#    'decis rule',
#    'other agent',
#    'properti',
#    'granul',
#    'parameter approxim space'],
#   ['approxim confid interv',
#    'approxim method',
#    'binomi proport',
#    'asymptot normal approxim',
#    'pseudo-)sampl',
#    'confid',
#    'unknown varianc',
#    'z - test',
#    'wald',
#    'higher coverag',
#    'failur'],
#   ['effici track',
#    'digit audio record',
#    'deform correl',
#    'simpl warp oper',
#    'stereo music',
#    'sinusoid signal',
#    'variou channel',
#    'complex manner',
#    'music fragment',
#    'dynam behavior',
#    'process',
#    'latter modif',
#    'repertoir',
#    'gener formula',
#    'implement',
#    'time',
#    'instantan valu'],
#   ['suppli chain',
#    'current manufactur model',
#    'mongolian archer',
#    'forrest research',
#    'great speed'],
#   ['pairwis thermal entangl',
#    'qubit chain',
#    'critic temperatur',
#    'heisenberg',
#    'pairwis',
#    'number'],
#   ['account inform polici',
#    'princip govern budget',
#    'taiwan',
#    'regul',
#    'resourc alloc',
#    'manag',
#    'time inform',
#    'nation resourc'],
#   ['icann',
#    'internet govern',
#    'internet domain name',
#    'dn',
#    'govern mechan',
#    'name system',
#    'regulatori regim',
#    'internet use',
#    'institut design',
#    'author',
#    'corpor',
#    'jurisdict'],
#   ['resolut reflect film',
#    'resolut pit',
#    'laser wavelength',
#    'convent rom',
#    'readout',
#    'numer apertur',
#    'dielectr layer',
#    'maximum cnr',
#    'optimum sb',
#    'thick',
#    'super -',
#    'diamet'],
#   ['linear multistep method',
#    'ordinari differenti equat',
#    'numer solut',
#    'contract',
#    'stabil result',
#    'initi valu',
#    'such method',
#    'autonom system'],
#   ['except safeti',
#    'handl object',
#    'c++ program',
#    'inherit hierarchi',
#    'oper',
#    'test',
#    'such complex'],
#   ['mail model', 'room', 'improv', 'post'],
#   ['web work', 'web integr', 'elead', 'compani'],
#   ['comput scienc field',
#    'berkeley',
#    'graduat degre',
#    'women',
#    '- tradit student',
#    'profession employ',
#    'mill',
#    'full professorship',
#    'leaki pipelin'],
#   ['dispos mobil phone', 'simplifi handset', 'busi model', 'nich market'],
#   ['pageflex',
#    'mediarich',
#    'data composit engin',
#    'layout',
#    'web',
#    'graphic innov',
#    'interfac'],
#   ['asymptot entangl measur',
#    'bipartit state',
#    'quantum',
#    'code capac',
#    'classic commun',
#    'local quantum oper',
#    'measur'],
#   ['memori parallel system',
#    'openmp',
#    'cach',
#    'ccnuma',
#    'hpf compil',
#    'program multipl data',
#    'portabl applic develop'],
#   ['compos architectur',
#    'petri net',
#    'time properti',
#    '- function properti',
#    'mss',
#    'net'],
#   ['frailti varianc estim',
#    'proport hazard model',
#    'maximum likelihood estim',
#    'semiparametr',
#    'em method',
#    'asymptot distribut',
#    'hazard',
#    'paramet',
#    'gamma',
#    'theta /sub',
#    'diseas data',
#    'small sampl',
#    'statist properti'],
#   ['agil busi', 'packard', 'vendor hewlett'],
#   ['optim control problem',
#    'plan problem',
#    'product plan',
#    'shortest path',
#    'multipl control function',
#    'train oper',
#    'graph',
#    'combinatori search',
#    'state problem',
#    'oper problem',
#    'numer comput',
#    'problem',
#    'bang'],
#   ['obliqu cut',
#    'curv shear surfac',
#    'uncut chip area',
#    'nose radiu tool',
#    'chip veloc',
#    'surfac area',
#    'rake',
#    'friction power',
#    'angl'],
#   ['citizen ident manag',
#    'public key infrastructur',
#    'egovern implement',
#    'identif applic',
#    'electron servic',
#    'centric ident',
#    'smart card',
#    'privat initi',
#    'standard',
#    'accept',
#    'societi'],
#   ['visibl cement data',
#    'exampl imag',
#    '- ray microtomographi',
#    'microstructur',
#    'plaster',
#    'd datafil',
#    'voxel size',
#    'european synchrotron radiat',
#    'micromet',
#    'common build',
#    'few data',
#    'advanc'],
#   ['genet regulatori system',
#    'period oscil',
#    'genet oscil',
#    'autoregulatori feedback loop',
#    'feedback loop',
#    'jump dynam',
#    'dynam',
#    'time delay',
#    'stabil region',
#    'protein system',
#    'simpl nonlinear model',
#    'hysteret properti',
#    'multipl time scale',
#    'posit feedback',
#    'gene',
#    'singular perturb',
#    'loop',
#    'biochem reaction',
#    'regul',
#    'possibl mechan'],
#   ['kutta discret',
#    'differenti algebra equat',
#    'numer',
#    'index',
#    'classic result',
#    'geometr properti',
#    'invari manifold result',
#    'exact solut',
#    'equilibrium',
#    'rung'],
#   ['anisotrop piezoelectr lamin',
#    'torsion vibrat',
#    'piezoelectr actuat',
#    'anisotrop composit lamin',
#    'vibrat',
#    'stiff method',
#    'anisotrop composit',
#    'lamin',
#    'twist coupl',
#    'harmon excit',
#    'structur coupl',
#    'twist',
#    'actuat',
#    'dynam analyt model',
#    'hamilton principl',
#    'plane displac',
#    'motion',
#    'parametr studi',
#    'model'],
#   ['zpl languag',
#    'arbitrari reduct',
#    'processor surpass',
#    'fortran',
#    'na implement',
#    'mg benchmark'],
#   ['regress test methodolog',
#    'test suit',
#    'databas modul',
#    'impact analysi techniqu',
#    'data flow',
#    'mainten activ',
#    'tabl trigger',
#    'integr constraint',
#    'call graph firewal',
#    'analysi issu',
#    'applic',
#    'case',
#    'such algorithm',
#    'difficulti'],
#   ['imag segment represent',
#    'imag segment',
#    'wavelet basi',
#    'wavelet',
#    'effici represent method',
#    'segment',
#    'imag qualiti'],
#   ['measur outlier',
#    'robust process techniqu',
#    'outlier reject',
#    'robust regress',
#    'measur nois',
#    'vibrat measur',
#    'line robust process',
#    'laser doppler vibromet',
#    'laser doppler',
#    'measur data',
#    'optic vibrat',
#    'measur drop',
#    'fourier spectra',
#    'regress techniqu',
#    'doppler',
#    'speckl drop',
#    'accuraci',
#    'process techniqu',
#    'out',
#    'frequenc respons function',
#    'laser',
#    'vibromet',
#    'nois'],
#   ['mothbal mania', 'telefonica movil', 'germani', 'unproven technolog'],
#   ['multicel convert',
#    'capacitor voltag',
#    'voltag constraint',
#    'input voltag',
#    'convert',
#    'switch',
#    'output waveform',
#    'control',
#    'appar frequenc',
#    'origin model',
#    'seri'],
#   ['distant illumin',
#    'convex lambertian object',
#    'surfac normal vector',
#    'spheric harmon',
#    'princip eigenmod',
#    'compon analysi',
#    'upper hemispher',
#    'imag',
#    'previou empir observ',
#    'variabl'],
#   ['timescal internet traffic',
#    'internet manag',
#    'traffic engin',
#    'congest control',
#    'packet basi',
#    'manag timescal',
#    'internet',
#    'hop',
#    'perform requir',
#    'servic offer',
#    'manag'],
#   ['advertis expens',
#    'insur compani',
#    'advertis',
#    'optim time',
#    'optim',
#    'maximum principl'],
#   ['haskel compil inlin',
#    'good compil',
#    'algorithm aspect',
#    'order languag',
#    'execut program',
#    'delic compromis',
#    'glasgow',
#    'unnecessari code bloat',
#    'good perform'],
#   ['robot learn',
#    'weight learn',
#    'time learn',
#    'autonom adapt control',
#    'statist neural network',
#    'classic control engin',
#    'humanoid robot arm',
#    'train',
#    'use represent',
#    'increment lwl',
#    'nonparametr statist',
#    'memori',
#    'real time',
#    'balanc',
#    'accur acquisit'],
#   ['petri net',
#    'concurr system',
#    'reachabl',
#    'context depend action',
#    'finit prefix',
#    'linear program problem',
#    'unfold'],
#   ['promot activ',
#    'librarian',
#    'inform centr',
#    'csir librari',
#    'servic',
#    'attitud'],
#   ['chaotic system', 'synchron scheme', 'observ', 'piecewis', 'robust'],
#   ['law firm innov', 'futur hing'],
#   ['attribut extract',
#    'data mine',
#    'good decis tree',
#    'associ rule',
#    'unseen data',
#    'data domain',
#    'featur',
#    'priori knowledg'],
#   ['hybrid fuzzi model',
#    'ph neutral process',
#    'local linear model',
#    'extrapol capac',
#    'simul result'],
#   ['oscillatori solut',
#    'numer integr',
#    'new algorithm',
#    'coeffici',
#    'code',
#    'step'],
#   ['shortest path enumer',
#    'failur state',
#    'state enumer problem',
#    'sequenti gener',
#    'best algorithm',
#    'network'],
#   ['unbalanc voltag condit',
#    'symmetri condit',
#    'voltag',
#    'symmetr',
#    'optim techniqu',
#    'phase',
#    'analyt equat'],
#   ['ventricular epicardi electrod',
#    'implant cardiovert defibril',
#    'left ventricl',
#    'epicardi stimul',
#    'stimul lead',
#    'advanc heart failur',
#    'implant',
#    'pace',
#    'sinu'],
#   ['visual design steer',
#    'graph morph',
#    'optim design',
#    'design',
#    'steer',
#    'constraint redund',
#    'scale multidisciplinari',
#    'effici',
#    'less cycl time',
#    'vd',
#    'method valid',
#    'develop'],
#   ['quantum memori',
#    'state quantum system',
#    'quantum inform',
#    'quantum oper',
#    'quantum',
#    'free quantum',
#    'decoher',
#    'extra qubit',
#    'thermal bath',
#    'ancilla process',
#    'auxiliari system',
#    'state',
#    'inform process',
#    'memori'],
#   ['hyperspectr data compress',
#    'hyperspectr data set',
#    'hyperspectr digit imageri',
#    'hyperspectr mapper',
#    'hyperion dataset',
#    'lossi compress algorithm',
#    'imageri collect experi',
#    'digit imageri',
#    'infrar spectromet',
#    'adapt princip',
#    'signific princip compon',
#    'dataset',
#    'small compress',
#    'hyperion',
#    'data integr',
#    'nois statist',
#    'pixel',
#    'mapper',
#    'aviri'],
#   ['interlibrari loan system',
#    'librari staff',
#    'clio databas',
#    'librari',
#    'student satisfact',
#    'clioweb',
#    'databas',
#    'washington colleg',
#    'better data manag',
#    'other institut',
#    'staff satisfact',
#    'student',
#    'cliorequest',
#    'faculti'],
#   ['quantum algorithm',
#    'classic comput',
#    'exponenti complex',
#    'fermion',
#    'time probabilist simul',
#    'algorithm',
#    'algebra',
#    'richard feynman',
#    'exact imit',
#    'dynam sign'],
#   ['monitor',
#    'm900',
#    'crt survey',
#    'fe950 +',
#    'philip 109s40',
#    'g420',
#    'pound',
#    'multiscan cpd',
#    'flexscan t766',
#    'soni',
#    'pr960f',
#    '920d',
#    'hitachi cm721fet',
#    'adi microscan',
#    't766',
#    'samsung syncmast',
#    'diamond pro',
#    '959nf'],
#   ['usabl',
#    'cost digit mainten',
#    'typic inform retriev',
#    'evalu',
#    'navig aid',
#    'paper manual',
#    'use'],
#   ['strobb graphic',
#    'commerci printer',
#    'newspap platesett',
#    'print market',
#    'polari name',
#    'ctp',
#    'success maker'],
#   ['hypoid bevel gear',
#    'gear tooth contact',
#    'tooth contact analysi',
#    'contact analysi',
#    'bevel',
#    'direct gear',
#    'curvatur properti',
#    'direct comput',
#    'automat differenti',
#    'tooth',
#    'geometr quantiti',
#    'nonlinear equat',
#    'gener mathemat model',
#    'oper',
#    'transmiss error',
#    'machin accuraci',
#    'path',
#    'ellips',
#    'methodolog',
#    'bound'],
#   ['consist split scheme',
#    'convect',
#    'boundari valu',
#    'diffus',
#    'stabil',
#    'reaction equat'],
#   ['quantum resistor network',
#    'electron wave',
#    'wire',
#    'waveguid',
#    'differ transmiss characterist',
#    'termin ring',
#    'buttik symmetri rule',
#    'multipl elast scatter',
#    'bohm',
#    'landauer',
#    'mani use logic',
#    'particular physic phenomena',
#    'quasi -',
#    'transport'],
#   ['surfac reconstruct',
#    '3d implicit surfac',
#    'tradit reconstruct algorithm',
#    'stereo rang imag',
#    'radial basi function',
#    '3d',
#    'comput vision',
#    'regular',
#    'point set',
#    'carv',
#    'implicit function',
#    'stereo',
#    'rang data',
#    'seamless model',
#    'optic rang'],
#   ['pdf subscript',
#    'other publish',
#    'sd time',
#    'advertis addit visibl',
#    'adob',
#    'york time',
#    'busi review'],
#   ['recruit',
#    'success retent',
#    'cse',
#    'graduat program',
#    'women',
#    'social scientist',
#    'student',
#    'comput',
#    'engin',
#    'workshop',
#    'experi'],
#   ['inform technolog workforc',
#    'women',
#    'research portfolio',
#    'nation scienc',
#    'nsf',
#    'underrepresent issu',
#    'opportun'],
#   ['haskel',
#    'xml',
#    'type represent',
#    'structur document',
#    'program style',
#    'valid xml document',
#    'domain specif languag',
#    'html',
#    'meta languag',
#    'combin librari',
#    'syntax',
#    'languag',
#    'parameter document',
#    'librari'],
#   ['upper semilattic',
#    'structur r',
#    'wtt/(a)=deg',
#    'contigu',
#    'nonzero element',
#    'sub t/(b'],
#   ['iodine-125 prostat',
#    'prostat implant',
#    'voxel size',
#    'dose',
#    'treatment plan softwar',
#    'dvh algorithm',
#    'accuraci',
#    'histogram',
#    'radioact seed',
#    'seed implant plane',
#    'millimet',
#    'comput speed'],
#   ['transient overflow probabl',
#    'markov fluid sourc',
#    'queue',
#    'gener markov',
#    'import sampl',
#    'rare event probabl',
#    'current buffer level',
#    'effici simul method',
#    'decay',
#    'comput complex',
#    'content distribut',
#    'larg deviat analysi',
#    'huge speed'],
#   ['fli phobia',
#    'virtual realiti treatment',
#    'exposur',
#    'incapacit',
#    'disord',
#    'scenario',
#    'effect',
#    'fp'],
#   ['new multipl algorithm',
#    'key cryptosystem',
#    'exponenti',
#    'hardwar architectur',
#    'serial ab',
#    'finit field',
#    'feedback shift regist',
#    'gf(2',
#    'lfsr',
#    'inner product'],
#   ['adapt compil',
#    'bias random search',
#    'genet algorithm',
#    'object function',
#    'local minima',
#    'predetermin order',
#    'transform'],
#   ['xml develop',
#    'gener markup languag',
#    'sgml',
#    'standard',
#    'technic paradigm',
#    'compat consider',
#    'extens'],
#   ['railway vr',
#    'vr simul system',
#    'safeti simul system',
#    'type simul',
#    'normal train oper',
#    'passeng'],
#   ['blood oxygen level',
#    'contrast mri',
#    'hyperoxia',
#    'pure oxygen',
#    'repres brain tissu',
#    'slow physiolog respons',
#    'signal intens',
#    'venou reaction',
#    'normal air',
#    'white matter',
#    'basal ganglia',
#    'blood',
#    'similar experi',
#    'evalu techniqu'],
#   ['statist process control',
#    'agil manufactur environ',
#    'x - chart',
#    'deviat',
#    'genet algorithm',
#    'doubl sampl',
#    'ds'],
#   ['spam act', '- spam suit', 'sprint', 'lawsuit', 'provid'],
#   ['util', 'pc', 'look'],
#   ['metal arc weld',
#    'electromagnet sensor',
#    'automat seam',
#    'track accuraci',
#    'laser displac',
#    'joint',
#    'eddi',
#    'root gap size'],
#   ['mani java develop',
#    'c++ destructor',
#    'systemat releas',
#    'garbag',
#    'critic resourc',
#    'tattletal techniqu',
#    'file handl',
#    'new class',
#    'transact',
#    'guarante'],
#   ['women student',
#    'comput scienc degre',
#    'recruit',
#    'stanford',
#    'cultur expect',
#    'retent',
#    'depart'],
#   ['dual wavelet frame',
#    'wavelet frame',
#    'nice dual wavelet',
#    'wavelet',
#    'canon dual frame'],
#   ['rough approxim map', 'set', 'classic indiscern', 'granul', 'distinct'],
#   ['rice dhpf compil',
#    'scalabl parallel perform',
#    'power compil analysi',
#    'fortran',
#    'bt benchmark',
#    'optim techniqu',
#    'na sp',
#    'hpf port',
#    'regular data'],
#   ['jackpot pay',
#    'stochast binari search',
#    'net revenu',
#    'random number gener',
#    'simul studi',
# ...
#    'qubit'],
#   ['branching-tim tempor logic ctl',
#    'ration agenc',
#    'clausal resolut',
#    'modal logic kd45',
#    'possibl belief',
#    'tempor logic',
#    'logic',
#    'repres belief',
#    'resolut',
#    'proof system',
#    'modal logic'],
#   ['editori system vendor', 'adob indesign', 'quark xpress', 'futur', 'mac'],
#   ['control chart pattern recognit',
#    'vector quantiz',
#    'fuzzy-soft learn vector quantiz',
#    'control chart',
#    'lvq',
#    'spc',
#    'fs-lvq',
#    'fuzzy-soft lvq',
#    'paper',
#    'fuzzy-soft competit learn network',
#    'pham',
#    'oztemel',
#    'lvq2'],
#   ['surrey counti council',
#    'voip makeov',
#    'swan project',
#    'countless lan',
#    'europ'],
#   ['inform access',
#    'deaf',
#    'tti commun',
#    'asl interpret',
#    'need',
#    'peopl',
#    'particular refer',
#    'loss present',
#    'practic tip'],
#   ['virtual famili',
#    'java program',
#    'virtual famili teach workshop',
#    'inform technolog',
#    'program',
#    'swift',
#    'british columbia'],
#   ['genet algorithm-neur network estim',
#    'cobb angl',
#    'torso surfac asymmetri',
#    'input torso indic',
#    'artifici neural network',
#    'torso asymmetri',
#    'genet algorithm'],
#   ['subject classif',
#    'librari inform system',
#    'li educ',
#    'li commun',
#    'legal inform'],
#   ['berkshir group', 'financ', 'fleetboston', 'fidel', 'compani'],
#   ['poliakov et al',
#    'current transient',
#    'psth respons',
#    'psth data',
#    'nois',
#    'psth',
#    'spike input',
#    'input spike',
#    'integrate-and-fir model'],
#   ['nonlinear parabol differenti equat',
#    'nonlinear parabol equat',
#    'runge-kutta method',
#    'converg',
#    'backward euler method',
#    'time discret',
#    'converg estim',
#    'exact solut'],
#   ['etact scintimammographi',
#    'angular dispar',
#    'degre',
#    'etact',
#    'etact project',
#    'smaller angular dispar',
#    'contrast',
#    'scintimammographi',
#    'improv',
#    'small tumor',
#    'comput tomographi',
#    'tumor contrast',
#    'spatial resolut',
#    'emiss',
#    'imag contrast',
#    'apertur',
#    'potenti'],
#   ['health level seven',
#    'standard hl7 messag format',
#    'extens hl7 encod',
#    'mom',
#    'hl7 messag object',
#    'extens hl7',
#    'hl7 encod',
#    'decod',
#    'hl7 messag string',
#    'encod',
#    'abstract hl7 messag form',
#    'health care environ',
#    'hl7 messag',
#    'mdr',
#    'hl7',
#    'standard encod rule',
#    'framework',
#    'design',
#    'implement',
#    'electron data exchang',
#    'intern standard',
#    'dispar comput applic',
#    'key set',
#    'standard',
#    'administr inform'],
#   ['mlp',
#    'accur meg sourc local',
#    'nois',
#    'real brain nois',
#    'meg system',
#    'hybrid mlp-start-lm',
#    'mlp',
#    'meg',
#    'multilay perceptron',
#    'sourc local',
#    'eeg',
#    'mlp structur',
#    'local error',
#    'white gaussian nois'],
#   ['catalog',
#    'desktop',
#    'workstat',
#    'librari',
#    'congress',
#    'tool aggreg',
#    'opportun time',
#    'internet',
#    'academ arl',
#    'onlin catalog tool',
#    'onlin document',
#    'develop'],
#   ['power qualiti event',
#    'power qualiti analysi',
#    'discret stft',
#    'discret short-tim fourier',
#    'signal process tool',
#    'signal process techniqu',
#    'comparison',
#    'stft',
#    'wavelet',
#    'analysi',
#    'power system',
#    'exampl',
#    'qualit comparison',
#    'emtp'],
#   ['inform depart',
#    'mutual benefit',
#    'academia',
#    'busi',
#    'academ cours',
#    'closer associ',
#    'inform profess',
#    'potenti benefit'],
#   ['technolog decis',
#    'servic choic manufactur',
#    'critic hardwar',
#    'futur',
#    'paper',
#    'softwar'],
#   ['physic size',
#    'aesthet prefer judgment',
#    'aesthet prefer',
#    'stimuli',
#    'particip',
#    'prefer judgment',
#    'influenc',
#    'abstract stimuli',
#    '3-year-old particip',
#    'larger stimuli',
#    'prefer pattern'],
#   ['probabilist control chart',
#    'averag run length',
#    'control chart',
#    'fuzzi approach',
#    'differ procedur',
#    'fuzzi',
#    'probabl theori',
#    'probabl approach',
#    'linguist data',
#    'differ degre'],
#   ['numer model',
#    'coronari arteri',
#    'coronari flow reserv',
#    'main hemodynam paramet',
#    'coronari arteri stenosi',
#    'cfr',
#    'fraction flow reserv',
#    'present studi',
#    'paramet',
#    'relationship',
#    'simpl geometr paramet',
#    'ffr valu',
#    'stenosi sever',
#    'blood flow',
#    'percent diamet stenosi',
#    'ffr'],
#   ['maximum balanc flow problem',
#    'gener maximum flow problem',
#    'total flow valu',
#    'gener flow'],
#   ['leucadia nation corp.', 'william commun', 'chapter'],
#   ['law librari user',
#    'local refer librari',
#    'internet resourc',
#    'broader view',
#    'librari'],
#   ['classic literatur',
#    'ancient histori',
#    'subject head',
#    'ancient greec',
#    'world view',
#    'librari',
#    'congress',
#    'ancient civil'],
#   ['intellig optim siev control',
#    'fact devic control',
#    'fact devic output region',
#    'multi-machin power system',
#    'fact devic',
#    'multi-machin system',
#    'optim control strategi',
#    'optim output',
#    'intellig optim siev',
#    'power system',
#    'output candid',
#    'intellig siev',
#    'iosc control',
#    'new method',
#    'invers system method'],
#   ['busi inform unit',
#    'busi inform profession',
#    'ethic dilemma',
#    'appli ethic',
#    'compet inform profession'],
#   ['product lifecycl manag',
#    'mainstream',
#    'plm',
#    'second-gener plm product',
#    'return-on invest'],
#   ['transient gate charg movement',
#    'ion channel',
#    'voltage-depend ion channel',
#    'calcium ion channel',
#    'shaker potassium channel gate',
#    'transient gate charg',
#    'gate charg',
#    'ion channel activ process',
#    'q-v relationship'],
#   ['mosaic pattern',
#    'cnn',
#    'variant templat',
#    'one-dimension cellular neural network mosaic pattern',
#    'infinit lattic',
#    'abund',
#    'spatial invari templat',
#    'finit',
#    'work'],
#   ['mammogram textur',
#    'clinic textur',
#    'synthet mammogram',
#    'synthet mammogram textur',
#    'mammogram',
#    'synthet imag',
#    'textur',
#    'compart',
#    'mean featur',
#    'clinic mammogram',
#    'mammogram synthesi',
#    'textur featur',
#    'radii',
#    'adipos tissu compart'],
#   ['new featur recognit algorithm',
#    'nation design repositori',
#    'algorithm',
#    'sun workstat',
#    'evalu',
#    'paper'],
#   ['wireless success',
#    'help-desk support',
#    'financ',
#    'ameritrad',
#    'rbc',
#    'help desk'],
#   ['model cut temperatur',
#    'temperatur correct factor model',
#    'insert',
#    'temperatur',
#    'effect',
#    'tool temperatur',
#    'cut temperatur',
#    'simpl tool geometri',
#    'materi'],
#   ['network-centr system', 'tradit graduat seminar format'],
#   ['special case', 'linear time', 'winner', 'two-play game', 'infinit durat'],
#   ['power-of-two coeffici quadratur mirror filter lattic filter bank',
#    'coeffici lattic structur quadratur mirror filter bank',
#    'novel genet algorithm',
#    'spt valu',
#    'genet oper',
#    'design',
#    'spt represent',
#    'new featur',
#    'spt',
#    'perform',
#    'power-of-two'],
#   ['transit petri net',
#    'transit petri',
#    'net evolut',
#    'record way',
#    'place',
#    'analysi',
#    'transit'],
#   ['onlin marketplac evolv', 'trade exchang', 'custom demand', 'manufactur'],
#   ['open-architectur precis motion control system',
#    'overal control system',
#    'control system',
#    'develop',
#    'dspace ds1004 dsp processor board',
#    'hardwar architectur',
#    'precis',
#    'constitu control compon',
#    'feedback control',
#    'softwar develop platform',
#    'control'],
#   ['magneto-opt disk',
#    'groov record method',
#    'new gigamo media',
#    'inch',
#    'new gigamo technolog',
#    'gigamo media',
#    'develop',
#    'record capac',
#    'land',
#    'msr',
#    'capac',
#    'downward compat',
#    'disk',
#    'media'],
#   ['enterpris program',
#    'common enterpris program mistak',
#    'mistak',
#    'common mistak',
#    'program',
#    'tip',
#    'book'],
#   ['mu m.',
#    'address dipol trap',
#    'far-detun dipol trap',
#    'scalabl configur',
#    'atom qubit',
#    'micro-opt realiz',
#    'quantum comput',
#    'red-detun laser beam',
#    'individu trap site',
#    'trap array',
#    'two-dimension array'],
#   ['sequenti toler control',
#    'set point',
#    'convent toler control',
#    'stc',
#    'sphere-fit method',
#    'earlier sphere-fit method',
#    'adapt',
#    'complex part',
#    'chronolog sequenc'],
#   ['internet video broadcast',
#    'video distribut system',
#    'multimedia applic',
#    'distanc learn',
#    'bandwidth estim',
#    'video stream',
#    'aggreg',
#    'smooth video stream',
#    'video',
#    'demand',
#    'statist estim',
#    'stream',
#    'develop algorithm',
#    'fundament role',
#    'futur broadband network',
#    'margin distribut',
#    'transmiss',
#    'qualiti',
#    'servic',
#    'result',
#    'paper',
#    'number'],
#   ['i&r servic', 'web access', 'web site'],
#   ['electron commerc',
#    'electron commerc programm',
#    'electron commerc profession',
#    'manag educ',
#    'electron commerc coursework race',
#    'kenneth bould',
#    'skill',
#    'standard',
#    'univers',
#    'role'],
#   ['gmaw process',
#    'gas-met arc',
#    'self-regul process',
#    'instabl phenomena',
#    'arc instabl',
#    'process',
#    'model',
#    'arc current'],
#   ['low earth orbit satellit',
#    'blind deconvolut resolut enhanc',
#    'starfir optic rang',
#    'adapt optic',
#    'undersampl imag sequenc',
#    'multifram',
#    'optic imageri',
#    'imag enhanc',
#    'blind deconvolut techniqu',
#    'blind deconvolut',
#    'imageri',
#    'focal plane array',
#    'focal plane array element',
#    'simul imageri',
#    'resolut loss',
#    'postprocess methodolog',
#    'method',
#    'gener',
#    'resolut',
#    'ground-bas telescop',
#    'spatial sampl',
#    'sub-nyquist sampl'],
#   ['univers variable-length sourc',
#    'admiss minimum rate',
#    'quantum state',
#    'code',
#    'optim quantum',
#    'quantum',
#    'probabl distribut',
#    'probabl',
#    'sens',
#    'expon'],
#   ['global cross',
#    'new investor',
#    'singapor technolog',
#    'hutchison telecommun'],
#   ['piezo-composit curv actuat',
#    'lipca',
#    'middl pzt ceram wafer',
#    'high cte',
#    'composit layer',
#    'design flexibl',
#    'design',
#    'lightweight fiber',
#    'manufactur',
#    'lightweight',
#    'cte',
#    'epoxi layer',
#    'elev temperatur',
#    'lightweight advantag',
#    'prepreg layer'],
#   ['chen system',
#    'canon lorenz attractor',
#    'complex chaotic system',
#    'simpl variabl constant control',
#    'chen attractor',
#    'new chaotic system'],
#   ['long data sequenc',
#    'coher receiv',
#    'fast fourier transform',
#    'signal',
#    'coher recept',
#    'correl',
#    'fast implement',
#    'fast convolut techniqu',
#    'fft',
#    'larg data window',
#    'match',
#    'implement'],
#   ['weak consist',
#    'wireless data access',
#    'wireless handheld devic',
#    'wireless data',
#    'data',
#    'weakli consist data access mechan',
#    'model',
#    'origin data entri',
#    'analyt model',
#    'ttl-base algorithm',
#    'respons time',
#    'mobil network',
#    'handheld devic',
#    'wireless commun cost'],
#   ['utc timescal',
#    'person comput clock',
#    'person comput',
#    'internet',
#    'minimum synch error',
#    'total synch error',
#    'time server',
#    'typic rm valu',
#    'clock',
#    'synch task',
#    'similar time station'],
#   ['expert system',
#    'financi problem domain',
#    'account',
#    'expert system problem domain',
#    'knowledg acquisit',
#    'financ',
#    'problem'],
#   ['softwar develop',
#    'component-bas softwar configur manag model',
#    'cbsd',
#    'softwar configur manag',
#    'scm'],
#   ['game machin',
#    'neumann-morgenstern game theori',
#    'individu ration',
#    'individu interest',
#    'classic mathemat formal',
#    'game theori',
#    'standard model',
#    'multiple-ag set',
#    'group interest',
#    'prefer',
#    'human behavior'],
#   ['passiv vibrat control',
#    'fraction differenti',
#    'suspens',
#    'vibrat isol',
#    'design',
#    'single-degree-of-freedom model',
#    'robust control',
#    'fraction deriv oper'],
#   ['serial manufactur system',
#    'dynam fractional-flow model',
#    'fractional-flow model',
#    'control properti',
#    'reachabl',
#    'rework',
#    'posit linear system',
#    'control'],
#   ['syndic',
#    'enterprise-wid content syndic technolog',
#    'offer',
#    'product',
#    'servic',
#    'marketplac',
#    'enterpris'],
#   ['simpl recurr network',
#    'lstm',
#    'nonregular languag',
#    'rodriguez',
#    'comparison',
#    'recurr net',
#    'srn'],
#   ['h famili mh',
#    'complet digraph',
#    'orthogon decomposit',
#    'isomorph copi',
#    'differ element'],
#   ['knapsack problem',
#    'series-parallel support',
#    'series-parallel graph',
#    'qkp',
#    'variant',
#    'graph structur',
#    'np-complet'],
#   ['three-dimension sagitt brain mr imag',
#    'autom cerebrum segment',
#    'cerebrum segment',
#    'cerebrum',
#    'cerebrum segment algorithm',
#    'midsagitt brain mr imag',
#    'mask',
#    'brain region(',
#    'cerebrum segment result',
#    'cerebrum imag',
#    'preliminari cerebrum segment',
#    'segment'],
#   ['comput scienc', 'femal comput scienc doctor', 'doctor'],
#   ['wind turbin voltag stabil control',
#    'mutual effect',
#    'power system stabil investig',
#    'wind turbin model',
#    'wind turbin power',
#    'voltag stabil',
#    'grid',
#    'grid-connect wind turbin',
#    'blade angl control',
#    'power grid'],
#   ['research firm outsel inc.',
#    'digit content provid',
#    'dick curti',
#    'digit content',
#    'disconnect',
#    'today',
#    'lead analyst'],
#   ['au = f',
#    'w-method',
#    'geometr theori',
#    'abstract banach space set',
#    'applic',
#    'stabil properti',
#    'term',
#    'split method'],
#   ['pda buyer', 'palm', 'hand', 'guid', 'person space'],
#   ['x. a',
#    'chromat spectrum',
#    'feasibl set',
#    'mix hypergraph',
#    'strict k-color',
#    'vertic',
#    'member'],
#   ['rfp process',
#    'telecom carrier',
#    'purchas process',
#    'purchas habit',
#    'current climat'],
#   ['popular data assimil techniqu',
#    'initi condit',
#    'data assimil',
#    'determinist model',
#    'local model error forecast',
#    'kalman filter type',
#    'error forecast',
#    'local model'],
#   ['feature-preserv volumetr techniqu',
#    'surfac triangul',
#    'adapt background grid',
#    'delaunay triangul method',
#    'background grid',
#    'distanc map',
#    'surfac featur',
#    'merg procedur',
#    'initi background grid',
#    'iso-surfac extract algorithm',
#    'surfac',
#    'final merg surfac',
#    'improv',
#    'isosurfac',
#    'main object',
#    'sharp edg',
#    'extract',
#    'point enrich techniqu',
#    'procedur',
#    'algorithm',
#    'grid gener',
#    'object',
#    'applic',
#    'comer',
#    'featur'],
#   ['electr transform', 'structur vibrat', 'adapt vibrat', 'design'],
#   ['trajectori optim approach',
#    'transient thermal respons',
#    'larg titanium alloy billet',
#    'billet temperatur distribut',
#    'total process time',
#    'control',
#    'design goal'],
#   ['model theori',
#    'finit superstructur',
#    'theori',
#    'isomorph',
#    'model-theoret properti',
#    'finit subset',
#    'countabl signatur'],
#   ['world wide web',
#    'html page',
#    'web',
#    'data extract',
#    'pre-defin schema',
#    'data',
#    'html form',
#    'invalu inform sourc',
#    'internet'],
#   ['induct motor drive',
#    'mechan speed sensor',
#    'motor shaft',
#    'sensorless control',
#    'motor termin',
#    'induct motor',
#    'rotor speed',
#    'low cost',
#    'high reliabl',
#    'measur stator voltag',
#    'steady-st speed accuraci',
#    'drive',
#    'rotor',
#    'attract',
#    'stator',
#    'fundament magnet flux wave',
#    'spatial orient',
#    'open-loop estim'],
#   ['abrupt chang',
#    'detect',
#    'freedom',
#    'estim',
#    'variabl',
#    'process',
#    'well-studi problem',
#    'degre',
#    'likelihood ratio statist',
#    'chi',
#    'parallel problem',
#    'normal mean',
#    'chang',
#    'change-point problem',
#    'gener likelihood ratio test statist',
#    'import problem',
#    'normal varianc',
#    'change-point',
#    'null distribut',
#    'exact analysi',
#    'distribut',
#    'varianc',
#    'lower bound'],
#   ['preced fire instruct',
#    'dataflow comput',
#    'sequenti program',
#    'sequenti process',
#    'preced',
#    'hardwar scale',
#    'control',
#    'dataflow machin',
#    'operand',
#    'process perform',
#    'remedi',
#    'total number'],
#   ['public access wlan', 'mick reev', 'dsl servic', 'chief technolog offic'],
#   ...]}

# %%
import pickle

with open('outputs_INSPEC.pkl', 'wb') as f:
    pickle.dump(outputs, f)

# %%
import pickle

with open('outputs_INSPEC.pkl', 'rb') as f:
    outputs = pickle.load(f)

# %% [markdown]
# Оценка моделей F1-метрикой

# %%
def evaluation(predictions, references):
    precision = len(set(predictions) & set(references)) / len(set(predictions))
    recall = len(set(predictions) & set(references)) / len(set(references))
    F1_metrics = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
    return F1_metrics

# %%
import numpy as np
evals = {}
for model in outputs:
    scores = []
    for output, reference in zip(outputs[model], references):
        scores.append(evaluation(output, reference))
    avg_score = np.mean(scores, axis = 0)
    evals[model] = round(avg_score, 2)
evals
# Out:
# {'KeyBERT': np.float64(0.26),
#  'Rake': np.float64(0.22),
#  'TextRank': np.float64(0.34),
#  'TopicRank': np.float64(0.29),
#  'YAKE': np.float64(0.34)}
