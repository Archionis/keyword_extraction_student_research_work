# %%
from datasets import load_dataset
import nltk
from tqdm import tqdm
import re
import spacy
from spacy.tokenizer import _get_regex_pattern
# Out:
# c:\Users\Maxim Zubarev\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# Создание датасета из файлов папки SemEval2010

# %%
import os
import glob
import re
from datasets import Dataset

def create_dataset(text_dir, keyphrases_dir):
    text_files = sorted(glob.glob(os.path.join(text_dir, "*.txt")))
    data = []
    for text_file in text_files:
        base_name = os.path.splitext(os.path.basename(text_file))[0]
        key_file = os.path.join(keyphrases_dir, f"{base_name}.key")
        with open(text_file, 'r', encoding='utf-8') as f:
            text = f.read()
        text = re.sub(r'[\n\r\t]+', ' ', text)
        text = re.sub(r'\s+', ' ', text)
        text = text.strip()
        with open(key_file, 'r', encoding='utf-8') as f:
            keyphrases = []
            for line in f:
                line = line.strip()
                if line:
                    cleaned_line = re.sub(r'[\n\r\t]+', ' ', line)
                    cleaned_line = re.sub(r'\s+', ' ', cleaned_line).strip()
                    if cleaned_line:
                        keyphrases.append(cleaned_line)     
        data.append({
            'id': base_name,
            'text': text,
            'keyphrases': keyphrases
        })
    dataset = Dataset.from_list(data)
    return dataset

dataset = create_dataset(r".\SemEval2010\docsutf8", r".\SemEval2010\keys")

# %%
dataset['text'][0]
# Out:
# 'Scalable Grid Service Discovery Based on UDDI* * Authors are listed in alphabetical order. Sujata Banerjee$ , Sujoy Basu$ , Shishir Garg , Sukesh Garg , Sung-Ju Lee$ , Pramila Mullan , Puneet Sharma$ $ HP Labs 1501 Page Mill Road Palo Alto, CA, 94304 USA +1-650-857-2137 {sujata.banerjee,sujoy.basu,sungju.lee,puneet.sharma}@hp.com France Telecom R&D Division 801 Gateway Blvd, # 500 South San Francisco, CA, 94080 USA +1 650 -875-1500 {shishir.garg,sukesh.garg,pramila.mullan}@francetelecom.com ABSTRACT Efficient discovery of grid services is essential for the success of grid computing. The standardization of grids based on web services has resulted in the need for scalable web service discovery mechanisms to be deployed in grids Even though UDDI has been the de facto industry standard for web-services discovery, imposed requirements of tight-replication among registries and lack of autonomous control has severely hindered its widespread deployment and usage. With the advent of grid computing the scalability issue of UDDI will become a roadblock that will prevent its deployment in grids. In this paper we present our distributed web-service discovery architecture, called DUDE (Distributed UDDI Deployment Engine). DUDE leverages DHT (Distributed Hash Tables) as a rendezvous mechanism between multiple UDDI registries. DUDE enables consumers to query multiple registries, still at the same time allowing organizations to have autonomous control over their registries.. Based on preliminary prototype on PlanetLab, we believe that DUDE architecture can support effective distribution of UDDI registries thereby making UDDI more robust and also addressing its scaling issues. Furthermore, The DUDE architecture for scalable distribution can be applied beyond UDDI to any Grid Service Discovery mechanism. Categories and Subject Descriptors C2.4 [Distributed Systems] General Terms Design, Experimentation, Standardization. 1. INTRODUCTION Efficient discovery of grid services is essential for the success of grid computing. The standardization of grids based on web services has resulted in the need for scalable web service Permission to make digital or hard copies of all or part of this work for personal or classroom use is granted without fee provided that copies are not made or distributed for profit or commercial advantage and that copies bear this notice and the full citation on the first page. To copy otherwise,to republish, to post on servers or to redistribute to lists, requires prior specific permission and/or a fee. MGC \'05, November 28- December 2, 2005 Grenoble , France discovery mechanisms to be deployed in grids. Grid discovery services provide the ability to monitor and discover resources and services on grids. They provide the ability to query and subscribe to resource/service information. In addition, threshold traps might be required to indicate specific change in existing conditions. The state of the data needs to be maintained in a soft state so that the most recent information is always available. The information gathered needs to be provided to variety of systems for the purpose of either utilizing the grid or proving summary information. However, the fundamental problem is the need to be scalable to handle huge amounts of data from multiple sources. The web services community has addressed the need for service discovery, before grids were anticipated, via an industry standard called UDDI. However, even though UDDI has been the de facto industry standard for web-services discovery, imposed requirements of tight-replication among registries and lack of autonomous control, among other things has severely hindered its widespread deployment and usage [7]. With the advent of grid computing the scalability issue with UDDI will become a roadblock that will prevent its deployment in grids. This paper tackles the scalability issue and a way to find services across multiple registries in UDDI by developing a distributed web services disc ...

# %% [markdown]
# Импортирование и редактирование языковой модели под слова с дефисами

# %%
nlp = spacy.load("en_core_web_sm")
re_token_match = _get_regex_pattern(nlp.Defaults.token_match)
re_token_match = f"({re_token_match}|\w+-\w+)"
nlp.tokenizer.token_match = re.compile(re_token_match).match
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Maxim Zubarev\AppData\Local\Temp\ipykernel_8264\2674231081.py:3: SyntaxWarning: invalid escape sequence '\w'
#   re_token_match = f"({re_token_match}|\w+-\w+)"

# %% [markdown]
# Обработка данных: стеммизация ключевых слов. Текст на лишние символы не обрабатывался

# %%
def preprocessing(dataset, nlp):
    keyphrases = []
    text = []
    for sample in tqdm(dataset):
        sample_keyphrases = []
        text.append(sample['text'])
        for keyphrase in sample["keyphrases"]:
            tokens = [token.text for token in nlp(keyphrase)]
            stemmed = [nltk.stem.snowball.SnowballStemmer('porter').stem(token.lower()) for token in tokens]
            sample_keyphrases.append(" ".join(stemmed))
        keyphrases.append(sample_keyphrases)
    return text, keyphrases

# %%
text, references = preprocessing(dataset, nlp)
# Out:
#   0%|          | 0/243 [00:00<?, ?it/s]
# 100%|██████████| 243/243 [00:23<00:00, 10.18it/s]

# %%
def extraction(model, text, references, stemmer, vectorizer=None):
    output = []
    for doc, reference in tqdm(zip(text, references)):
        n = len(reference)
        match model.__class__.__name__:
            case 'KeyBERT':
                keywords = model.extract_keywords(
                    doc,
                    keyphrase_ngram_range=(1, 3),
                    vectorizer=vectorizer,
                    use_mmr=True,
                    diversity=0.7,
                    top_n=n * 2)
                stemmed = []
                for kw, score in keywords:
                    words = kw.split()
                    stemmed_words = [stemmer.stem(word.lower()) for word in words]
                    stemmed_phrase = " ".join(stemmed_words)    
                    stemmed.append(stemmed_phrase)
                output.append(stemmed[:n])
            case 'Rake':
                model.extract_keywords_from_text(doc)
                keywords = model.get_ranked_phrases()
                stemmed = []
                for kw in keywords:
                    words = kw.split()
                    stemmed_words = [stemmer.stem(word.lower()) for word in words]
                    stemmed_phrase = " ".join(stemmed_words)    
                    stemmed.append(stemmed_phrase)
                output.append(stemmed[:n])
            case _:
                model.load_document(input=doc)
                model.grammar_selection(grammar="NP: {<ADJ>*<NOUN|PROPN>+}")
                model.candidate_weighting()
                output.append([keyword for keyword, rank in model.get_n_best(n=n, stemming=True)])
    return output

# %% [markdown]
# Извлечение слов. Максимальная длина n-грама 3. KeyBERT использует пользовательский векторизатор, учитывающий грамматическую связь слов

# %%
from pke.unsupervised import TextRank, TopicRank, YAKE
from CustomVectorizer import CustomVectorizer
from nltk.corpus import stopwords
from keybert import KeyBERT
from rake_nltk import Rake
nltk.download('stopwords')
nltk.download('punkt')
stemmer = stemmer = nltk.stem.snowball.SnowballStemmer('porter')
nlp = spacy.load("en_core_web_sm")
vectorizer = CustomVectorizer(
    nlp_model=nlp,
    ngram_range=(1, 3),
    stop_words='english')
outputs = {}
for model in [KeyBERT, Rake, TextRank, TopicRank, YAKE]:
    extractor = model()
    if extractor.__class__.__name__ == 'Rake':
        extractor = model(stopwords=stopwords.words('english'), language='english', max_length=3)
    outputs[extractor.__class__.__name__] = extraction(extractor, text, references, stemmer, vectorizer=vectorizer)
outputs
# Out:
# WARNING:tensorflow:From c:\Users\Maxim Zubarev\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package stopwords to C:\Users\Maxim
# [nltk_data]     Zubarev\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Maxim
# [nltk_data]     Zubarev\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 243it [20:27,  5.05s/it]
# 243it [00:20, 11.89it/s]
# 243it [07:25,  1.83s/it]
# 243it [22:10,  5.47s/it]
# 243it [07:38,  1.89s/it]
# {'KeyBERT': [['grid servic discoveri',
#    'sap',
#    'ieee intern srd',
#    'web servic permiss',
#    'iptp',
#    'uddi deploy',
#    'simpl replic',
#    'other distant node',
#    'qo framework',
#    'xmln',
#    'ogsi wg',
#    'franc telecom',
#    'http://www.planet-lab.org',
#    'acm middlewar',
#    'comput repair',
#    'v2 specif',
#    'new local registri',
#    'scale issu',
#    'hash tabl data'],
#   ['sensor deploy strategi',
#    'network target detect',
#    'path exposur',
#    'drive madison',
#    'data fusion',
#    'alarm',
#    'dijkstra"',
#    'consensu decis',
#    'awgn nois',
#    'mobil radio servic',
#    'cost function',
#    'virtual point a',
#    'larger region',
#    '≤ n'],
#   ['voip audio conferenc',
#    'activ client',
#    'address alloc architectur',
#    'media handl solut',
#    'variou confer size',
#    'scalabl framework',
#    'transport protocol',
#    'network delay',
#    'system mix',
#    'session descript',
#    'multi parti',
#    'ieee itr',
#    'realiti',
#    'bangalor',
#    'loud number',
#    'top nmax stream'],
#   ['swarm worm',
#    'wireless system secur',
#    'invas softwar',
#    'slammer',
#    'vulner assess',
#    'disabl mcafe',
#    'countermeasur system',
#    'common http request',
#    'stealthi disabl',
#    'unsophist replic',
#    'lakesid avneu',
#    'fastest comput',
#    'differ target host',
#    'success scan'],
#   ['modular protocol',
#    'serviceand event',
#    'sdl project',
#    'intern symposium',
#    'defin gener notion',
#    'semant link',
#    'execut',
#    'clear implement',
#    'dynam updat',
#    'request req',
#    'represent represent',
#    'hat linux',
#    'local replac'],
#   ['data avail',
#    'center wide mainten',
#    'replic administrator"',
#    'iscsi virtual',
#    'server migrat step',
#    'new network function',
#    'live wan',
#    'environ connect chang',
#    'internet suspend',
#    'robust cooper context',
#    'deliveri',
#    'checkpoint boundari',
#    'remot site'],
#   ['mobil applic adapt',
#    'middlewar support',
#    'metric collect',
#    'mobjectmetricscollectionoverheadmmco(m',
#    'object contain',
#    'system wide optimis',
#    'java virtual machin',
#    'transport manag model',
#    'entiti criterion runtim',
#    'individu proxymethodmetricscontain',
#    'remot execut',
#    'servic qualiti',
#    'storag requir',
#    'recurs softwar'],
#   ['parallel download',
#    'server workload adjust',
#    'data movement protocol',
#    'adjust coalloc',
#    'symmetr multiprocessor',
#    'disk avail',
#    'altern reassembl mechan',
#    'alloc agent',
#    'o transfer rate',
#    'intens scientif applic',
#    'block size',
#    'java cog',
#    'delet replica',
#    'datagrid prototyp',
#    'time cost',
#    'leastsiz criterion'],
#   ['network local',
#    'beacon',
#    'effici surveil system',
#    'offsetttt spotlightnodeglob +',
#    'small rang',
#    'photo sensor dti',
#    'mica2 mote',
#    'cm optim event',
#    'error correct mechan',
#    'deploy site',
#    'cost special hardwar',
#    'same devic',
#    'detectednotiseventfals',
#    'differ aerial point'],
#   ['biolog sequenc comparison',
#    'high throughput blast',
#    'dedic grid environ',
#    'practic schedul scheme',
#    'parallel compil',
#    'adapt task',
#    'search tool',
#    'seed step',
#    'first tss alloc',
#    'score segment pair',
#    'packageblast execut',
#    'unseg databas',
#    'node name',
#    'scientif institut',
#    'main memori hd'],
#   ['molecular conform search',
#    'advanc comput scienc',
#    'space search programs[1',
#    'g perform',
#    'rpc select',
#    'grid technolog research',
#    'interconvers',
#    'conflex sequenti version',
#    'data persist',
#    'larger bio -',
#    'hpc1 hpc2',
#    'http://setiathome.ssl.berkeley.edu/.',
#    'dock applic',
#    'nation institut'],
#   ['avail grid resourc',
#    'adapt comput',
#    'applic run',
#    'central server',
#    'simpl localityawar',
#    'artifici load',
#    'refer',
#    'overload network link',
#    'accur migrat decis',
#    'differ processor speed',
#    'ieee int"l symp',
#    'current effici',
#    'variou set',
#    'heterogen world',
#    'intraclust commun',
#    'nonadapt version',
#    'globu toolkit',
#    'random work steal'],
#   ['scalabl reliabl multicast',
#    'bandwidth overlay tree',
#    'entir parent stream',
#    'particip node',
#    'bloom filter',
#    'internet run',
#    'perpendicular download',
#    'mani current overlay',
#    'distribut system',
#    'redund tornado',
#    'point',
#    'bottleneck algorithm',
#    'singl sourc',
#    'allow receiv',
#    'tree" root',
#    'friendli transport'],
#   ['peer file share',
#    'node local document',
#    'googl desktop',
#    'lucen framework',
#    'document identif number',
#    'intranet joshua',
#    'prior specif permiss',
#    'import file',
#    'standalon applic',
#    'apocrita goal',
#    'user"',
#    'differ revis',
#    'temporari directori',
#    'secur unicast pipe',
#    'avail onlin'],
#   ['peer cach',
#    'perform object storag',
#    'network transfer object',
#    'consist access',
#    'buddycach transact valid',
#    'hybrid web',
#    'explicit client interact',
#    'fast crash recoveri',
#    'alerthelp latenc',
#    'grain coher techniqu',
#    'base thor storag',
#    'first usenix',
#    'commit cost',
#    'gb',
#    'toler call'],
#   ['context provid',
#    'key laboratori',
#    'central select mechan',
#    'european softwar engin',
#    'application" satisfact',
#    'negoti round',
#    'bing shi',
#    'technolog nanj',
#    's2',
#    'proactiv action',
#    'reserv util'],
#   ['secur key distribut',
#    'cluster id',
#    'wireless sensor',
#    'protocol',
#    'hypercub interconnect network',
#    'ham distanc',
#    'logic space h(k',
#    'setup server',
#    'safeti path vector',
#    'deploy round',
#    'pair',
#    'batteri energi'],
#   ['event encrypt',
#    'enforc publish',
#    'domain access control',
#    'usenix secur symposium',
#    'middlewar system',
#    'contentbas rout',
#    'pub pub sub',
#    'own marshal mechan',
#    'current broker',
#    'larg dynam group',
#    'refresh schedul',
#    'process overhead'],
#   ['peer stream',
#    'parent overlay structur',
#    'bloom filter',
#    'new gossip messag',
#    'outbwi outgo access',
#    'exhibit limit scalabl',
#    'receiv detect',
#    'deliveri mechan',
#    'applic layer',
#    'primari design goal',
#    'random delay',
#    'mainten scheme',
#    'rel network distanc'],
#   ['packet loss',
#    'playout buffer algorithm',
#    'interact speech',
#    'intraflow qo',
#    'short annoy burst',
#    'ifip tc6',
#    'protect scheme',
#    'drop tail',
#    'the"g.7i9 encod',
#    'main payload',
#    'i( mod',
#    'qualiti improv',
#    'ulp = elp',
#    'differ prioriti level',
#    'error recoveri',
#    'pcm signal',
#    'weak point',
#    'gener util function',
#    'resynchron time',
#    'appropri linear predict',
#    '- hop topolog',
#    'k compens'],
#   ['dynam virtual environ',
#    'geometri data schedul',
#    'server throughput',
#    'spectat entiti',
#    'index full edg',
#    'grid cell',
#    'onlin game',
#    'visibl distanc',
#    'user aoi detect',
#    'tree',
#    'smaller partit',
#    'second life',
#    'object hash',
#    'locat updat request'],
#   ['adapt resourcemanag middlewar',
#    'stream servic',
#    'dre system',
#    'qo requir',
#    'hybrid adapt',
#    'redhat linux',
#    'lower prioriti',
#    'hyarm applic adapt',
#    'emerg respons applic',
#    'cpu monitor',
#    'packet loss ratio',
#    'sender',
#    'continu control variable(',
#    'http://www.ex-parrot.com/∼pdw/iftop/',
#    'corba specif',
#    'uav camera video'],
#   ['reservoir model',
#    'ensembl kalman filter',
#    'assimil',
#    'enkf data',
#    'sever petroleum',
#    'industri standard simul',
#    'remot comput cluster',
#    'texa advanc',
#    'convent mpi implement',
#    'comput accuraci',
#    'name host pingluo',
#    'specif batch',
#    'discret cosin parameter',
#    'instal guid',
#    'globu function',
#    'pacman distribut',
#    'output_files=001.out.tar'],
#   ['sensor node local',
#    'indoor system evalu',
#    'exact locat',
#    'wsn',
#    'maximum delay uncertainti',
#    'radio irregular',
#    'anchor set',
#    'updatemap',
#    'event cost',
#    'data process platform',
#    'air blast propag',
#    'group distanc rank'],
#   ['sensor network local',
#    'passiv optic compon',
#    'lighthous locat',
#    'night time detect',
#    'aerial devic project',
#    'node color',
#    'neighbor tabl inform',
#    'label λj2',
#    'local consist',
#    'record imag',
#    'hardwar consum energi',
#    'constraint',
#    'differ zoom factor'],
#   ['archiv sensor data',
#    'tini aggreg servic',
#    'intermedi data element',
#    'manag metadata',
#    'gigabyt scale storag',
#    'graph lookup',
#    'queri support interv',
#    'complex read request',
#    'scalabl overlay network',
#    'index hash',
#    'highest level skip',
#    'proxi proxi record',
#    'updat perform',
#    'elsevi journal',
#    'insert summari',
#    'quad tree',
#    'solar power cell',
#    'integ'],
#   ['larg rang queri',
#    'mani sensor network',
#    'central indic',
#    'geograph embed',
#    'datacentr storag system',
#    'gpsr implement',
#    'network size dim',
#    'skew data distribut',
#    'consist hash scheme',
#    'skip graph',
#    'scalar valu',
#    '← nil',
#    'mobil sink',
#    'node" local replica',
#    'averagecostperqueryinexponentialdistribut',
#    'such neighbor',
#    'light level'],
#   ['opportunist rout protocol',
#    'realist mobil',
#    'unlimit replic',
#    'epidem figur',
#    'total contact durat',
#    'excess commun',
#    'full wifi coverag',
#    'confer environ',
#    'real trace',
#    'end connect',
#    'low deliveri ratio',
#    'tradit mobil ad',
#    'design tradeoff',
#    'hop count',
#    'most storag usag',
#    'secur technolog studi',
#    'ns2',
#    'exchang index',
#    'mac address'],
#   ['sensor network applic',
#    'rescu system',
#    'site storag capabl',
#    'cellular recept',
#    'cenwit cost',
#    'fetch locat inform',
#    'campu box',
#    'uniqu node',
#    'modern search',
#    'scaveng techniqu',
#    'singl alkalin batteri',
#    'raw data',
#    'yosemit nation park',
#    'basic prototyp'],
#   ['dead reckon',
#    'zero network delay',
#    'fair',
#    'central game server',
#    'compens techniqu',
#    'messag deliveri mechan',
#    'vector schedul',
#    'continu interact media',
#    'flop effect',
#    'averag method',
#    'receiver" frequenc',
#    'farthest player',
#    'higher varianc case',
#    'zj ik'],
#   ['global synchron',
#    'lag valu',
#    'dead reckon scheme',
#    'game protocol design',
#    'consist definit',
#    'sate updat',
#    'ntp',
#    'remot site sp',
#    'game develop',
#    'real state',
#    'acm multimedia',
#    'physic speed limit',
#    'inconsistency(pixel'],
#   ['larg onlin data',
#    'interact map site',
#    'access approach',
#    'recent peer',
#    'client java',
#    'spatial attribut',
#    'platform independ',
#    'central directori',
#    'run databas',
#    'dynam updat',
#    'upload oper',
#    'actual servic',
#    'simpl imag viewer',
#    'brabec hanan',
#    'georgia',
#    'www.cs.umd.edu/{~egemen,~brabec,~hj'],
#   ['context awar comput',
#    'wlan posit system',
#    'share facil',
#    'interact support aloi',
#    'user" contact',
#    'group member chang',
#    'http://www.aim.com/',
#    'avail statu',
#    'new rfid tag',
#    'linz'],
#   ['grid comput architectur',
#    'avail node',
#    'extern process server',
#    'isol task',
#    'monitor',
#    'data resourc share',
#    'process pc figur',
#    'autonom administr domain',
#    'specif tool',
#    'group server group',
#    'sun',
#    'virtual machin rmi',
#    'campina campina',
#    'execut finish',
#    'swindew',
#    'flow diagram'],
#   ['correspond congest game',
#    'cglf',
#    'loaddepend failur',
#    'resourc cost',
#    'task complet',
#    'comput complex',
#    'same strategi',
#    'group util',
#    's - stabil',
#    'acm symposium',
#    'life applic',
#    'iit haifa',
#    'onli agent'],
#   ['scalabl aggreg tree',
#    'global hash',
#    'sdim implement',
#    'unstructur gossip protocol',
#    'basic file system',
#    'manag layer',
#    'lookup servic',
#    'node" nodeid',
#    'detail view',
#    'declar logic',
#    'api function',
#    'worm detect',
#    'mogul',
#    'local applic',
#    'definit',
#    's. shenker',
#    'austin',
#    'publishsubscrib',
#    '25(4):367',
#    'peer do'],
#   ['spectrum content manag',
#    'continu stream',
#    'actual storag',
#    'network heterogen comput',
#    'alon digit video',
#    'name content',
#    'media endpoint figur',
#    'asynchron remot access',
#    'socket layer',
#    'recommend system',
#    'confer'],
#   ['game proxi',
#    'multicast',
#    'server network architectur',
#    'author assign techniqu',
#    'fast game flow',
#    'fair messag exchang',
#    'persist transport session',
#    'player" own death',
#    'overal game state',
#    'client side predict',
#    'sever scalabl problem',
#    'suffici cheat deter',
#    'combat',
#    'event updat',
#    'oper system support'],
#   ['network competit',
#    'monitor protocol',
#    'isp introduc',
#    'polic illeg contract',
#    'innov characterist',
#    'servic differenti',
#    'account properti',
#    'inform signal',
#    'follow requir',
#    'monitor correspond',
#    'payment schedul',
#    'definit',
#    'anonym review'],
#   ['acoust sniper local',
#    'mobil countersnip system',
#    'ieee 802.14.5',
#    'weapon type',
#    'fusion algorithm" abil',
#    'event encod sensor',
#    'shockwav aoa measur',
#    'multipl toa',
#    'gp antenna',
#    'standoff distanc',
#    'aberdeen test',
#    'usenix intern',
#    'dedic gpio',
#    'joint time frequenc',
#    'technolog evalu',
#    'be0'],
#   ['web servic workflow',
#    'optimum schedul assign',
#    'other qo metric',
#    'autonom comput',
#    'concurr level',
#    'cluster',
#    'servic provid degrad',
#    'advanc deploy scenario',
#    'exponenti search',
#    'itinerari',
#    'composit languag',
#    'altern queri execut',
#    'runningtimeinsecond',
#    'highest busi valu',
#    'percentageofallserviceprovid number'],
#   ['os x',
#    'design educ',
#    'comput resourc',
#    'maya applic',
#    'end graphic',
#    'miller ringl',
#    'gb ram',
#    'nonlinear video edit',
#    'futur artist',
#    'accredit fouryear colleg',
#    'screen saver',
#    'new technolog deploy',
#    'lost process time',
#    '19]xgrig',
#    'trail sarasota',
#    'mont carlo calcul',
#    'solid state',
#    'nativ method',
#    'render test',
#    'multipl logic grid'],
#   ['avail latenc',
#    'peer vehicular ad',
#    'c2p2 network',
#    'replica alloc method',
#    'carrier',
#    'car densiti',
#    'data mule',
#    'design tradeoff',
#    'term zebroid',
#    'replac polici',
#    'client" request',
#    'video clip',
#    'applic requir',
#    'item repositori',
#    'spars assumpt',
#    'bias popular',
#    'predict accuraci metric',
#    'et al',
#    'differ frequenc distribut'],
#   ['nativ pda browser',
#    'remot display protocol',
#    'mobil user',
#    'pthinc prototype" lack',
#    'smaller screen',
#    'intens web helper',
#    'wireless access point',
#    'thinclient solut',
#    'server comput power',
#    'overlay surfac',
#    'page load test',
#    'citrix metafram',
#    'client downsampl',
#    'ing benchmark',
#    'direct scroll',
#    'key session',
#    'virtual devic driver',
#    '3com palmpilot',
#    '% pthincicavncrdploc videoqu',
#    'user interfac metaphor'],
#   ['group sensor node',
#    'transmit distanc',
#    'honeycomb structur',
#    'redund wsn',
#    'greedi solut',
#    'local algorithm',
#    'distribut index',
#    'neighbor"',
#    'coverag qualiti',
#    'arbitrari point',
#    'net mind',
#    'deduct algorithm'],
#   ['increment gossip protocol',
#    'dynam spectrum alloc',
#    'http://www.internetnews.com/wireless/article.php/3513721',
#    'cost sens equip',
#    'tv broadcast',
#    'nabeel',
#    'propag distanc',
#    'larg deploy',
#    'particular frequenc band',
#    'data chang',
#    'such share',
#    'more coin toss',
#    'mac layer',
#    'granular',
#    'cheriton school'],
#   ['asynchron messag middlewar',
#    'mobil comput system',
#    'hoc environ',
#    'protocol increas',
#    'backbon network',
#    'client prototyp',
#    'aim',
#    '802.11g',
#    'microsoft msmq',
#    'frequent disconnect',
#    'softwir ag',
#    'java rmi',
#    'servic specif version',
#    'london'],
#   ['grid intrus detect',
#    'centralis idss',
#    'workflow servic',
#    'platformindepend interfac',
#    'differ implement',
#    'integr',
#    'analys level',
#    'simul environ',
#    'differenti network',
#    'phase process architectur',
#    '-ident -version -descript',
#    'registri',
#    'multipl host',
#    'symposium'],
#   ['servic event correl',
#    'improv fault manag',
#    'ieee network',
#    'intern symposium',
#    'custom report figur',
#    'snmp trap',
#    'gruschke" depend graph',
#    'web host offer',
#    'resolut time',
#    'download failur',
#    'role user'],
#   ['effici protocol',
#    'transit reduct',
#    'immedi predecessor track',
#    'relev causal past',
#    'event number ipt1',
#    'correspond process',
#    'comput emmanuel',
#    'checkpoint problem',
#    'strict partial order',
#    'hass diagram',
#    'addit control messag',
#    '≥ send(m).v',
#    'whole vector clock',
#    'acm transact',
#    'predic ci(j',
#    'addit piggyback',
#    'consist cut',
#    'journal',
#    'lamport"'],
#   ['autonom compon',
#    'middlewar interact',
#    'smart transduc interfac',
#    'inform bu',
#    'specif packag',
#    'context attribut',
#    'heterogen network',
#    'qo properti',
#    'oper system review',
#    'clusterto',
#    'addit wireless network',
#    'raw physic data',
#    'time schedul strategi',
#    'respons',
#    'microcontrol famili c167',
#    'uniqu identifi',
#    'deploy',
#    'definit',
#    'interrupt event channel',
#    'state chang'],
#   ['manet p2p system',
#    'level mobil comput',
#    'balanc load',
#    'scalabl servic discoveri',
#    'reloc algorithm',
#    'papadopouli',
#    'distribut scheme',
#    'thailand',
#    'hop',
#    'subsequ control packet',
#    'logic overlay',
#    'engin kasetsart',
#    '- resourc',
#    'nondata node'],
#   ['oper context theori',
#    'complet ot solut',
#    'concurr updat',
#    'execut form',
#    'level undo command',
#    'systemat approach',
#    'reus',
#    'flexibl notif framework',
#    'time groupwar',
#    'complex puzzl scenario',
#    'essenti correct requir',
#    'differ control algorithm',
#    'global sequenc',
#    'causal relat',
#    'vector logic clock',
#    'transform version',
#    '= it(o3',
#    'invok',
#    'properti cot',
#    'collabor edit session',
#    'spreadsheet',
#    'recurs call'],
#   ['adapt databas cach',
#    'peer storag util',
#    'consist requir',
#    'middlewar layer',
#    'applic specif data',
#    'postprocess',
#    'cryptograph hash function',
#    'differ workload',
#    'open sourc mysql',
#    'end web server',
#    'java object',
#    'duplic transfer detect',
#    'dabek',
#    'virtual machin',
#    'mirror',
#    'gb',
#    'signific common',
#    'usenix winter'],
#   ['energi harvest framework',
#    'wireless sensor',
#    'environ awar decis',
#    'total system util',
#    'better effici',
#    'abov optim problem',
#    'weather forecast servic',
#    'senor node',
#    'low power mode',
#    'residu batteri statu',
#    'cycl',
#    'dynam voltag',
#    'defin',
#    'network latenc',
#    'slot continu duti',
#    'sampl frequenc',
#    'storag data'],
#   ['pervas document manag',
#    'categori editor',
#    'gall@ifi.unizh.ch abstract collabor',
#    'manag system stefania',
#    'concurr issu',
#    'peer network',
#    'taskinst',
#    'indent refer',
#    'lineag inform',
#    'file externalfil',
#    'frequent use',
#    'definit',
#    'checkwriteaccess(',
#    'versionnumb use',
#    'textel',
#    'meta data restrict'],
#   ['network selfish server',
#    'replica misplac',
#    'game nash',
#    'optimist price',
#    'equilibrium solut',
#    'anarchi decreas',
#    'latter incent',
#    'linear program relax',
#    'desir global properti',
#    'dynam protocol converg',
#    'theoret comput scienc',
#    'capac limit',
#    'white node',
#    'cach object',
#    'onlin median',
#    'payment model',
#    'construct proof',
#    'poa complet graph',
#    'byung'],
#   ['decentr adapt servic',
#    'eda architectur',
#    'virtualis',
#    'dynam resourc',
#    'comput commun network',
#    'host e host',
#    'grid program',
#    'interact user access',
#    'activ replic',
#    'javasymphoni',
#    'system load',
#    'extend version',
#    'node level',
#    'reded concept'],
#   ['document cluster',
#    'global smooth regular',
#    'smallest eigenvector',
#    'mani benchmark dataset',
#    'label predictor',
#    'tri - factor',
#    'smart idea',
#    'λi wi',
#    'major intern event',
#    'converg',
#    'clgr algorithm',
#    'wk .'],
#   ['imag retriev relev',
#    'activ learn framework',
#    'laplacian regular regress',
#    'unlabel sampl',
#    'lod algorithm',
#    '% perform improv',
#    'maxim refin',
#    'user" feedback',
#    'ninth acm',
#    'cross valid',
#    'i. jordan',
#    'natur color',
#    'maximum eigenvalu'],
#   ['snippet gener perform',
#    'larg web collect',
#    'filesystem search',
#    'bias summari',
#    'lexicon meta data',
#    'result page',
#    'cach copi',
#    'gener pattern match',
#    'baseline(zlib',
#    'document reorder',
#    'excit log',
#    'queri frequenc distribut',
#    'small compress loss',
#    'spam'],
#   ['search result caption',
#    'search engin perform',
#    'stereotyp navig queri',
#    'url featur',
#    'optim snippet length',
#    'similar relev',
#    'live queri log',
#    'user behavior',
#    'multidocu summar',
#    'english interfac',
#    'acknowledg',
#    'clickthrough invers methodolog',
#    'kincaid readabl score'],
#   ['web search interact',
#    'suggest uptak',
#    'destin term',
#    'popular bar',
#    'domain shortcut',
#    'activ log',
#    'uniqu browser window',
#    'larg user pool',
#    'consecut queri',
#    'page visit',
#    'white microsoft',
#    'addit interfac featur',
#    'smooth tf.idf'],
#   ['effici cach',
#    'search engin queri',
#    'post list',
#    'futur queri stream',
#    'static index',
#    'similar trend',
#    'such onlin decis',
#    'http://www.yahoo.co.uk',
#    'stem',
#    'log',
#    'answer satur',
#    'novemb',
#    'much work',
#    'et al',
#    'multipl site',
#    'b. croft',
#    'acm sigir',
#    'gionis1 gionis@yahoo-inc.com',
#    'standard knapsack'],
#   ['prune index',
#    'scalabl search engin',
#    'top match page',
#    'independ document qualiti',
#    'term relev score',
#    'predict cach',
#    'incom queri',
#    'tier 1st',
#    'greedi polici',
#    'answer comput cost',
#    'result guarante',
#    'optim size',
#    'popular techniqu',
#    'sigmod record',
#    'better job',
#    'fact',
#    'antoulas@microsoft.com junghoo'],
#   ['document topic segment',
#    'multipl document bingjun',
#    'best term cluster',
#    'weight mutual inform',
#    'event track',
#    'overlap sentenc',
#    'similar page',
#    'singledocu case',
#    'relat research',
#    'newswir',
#    'lda',
#    'person write style',
#    'speech data',
#    'pmitra,giles,jyen}@ist.psu.edu',
#    'subtl task',
#    'best solut',
#    'algorithm converg',
#    'intern node',
#    'anisotrop diffus',
#    'wmik term',
#    'multipl surfac'],
#   ['event period classif',
#    'aperiod',
#    'subject descriptor',
#    'noisi featur',
#    'dynam stopword remov',
#    'word document',
#    'truncat gaussian',
#    'bursti period doc',
#    'real news stream',
#    'benchmark comparison',
#    'domin frequenc',
#    'http://www.google.com/alert',
#    'key idea',
#    'xke 2πi'],
#   ['person search result',
#    'queri expans techniqu',
#    'term pagerank',
#    'electron lexic databas',
#    'short keyword',
#    'mine anchor',
#    'index time',
#    'web applic',
#    'term frequenc',
#    'user" topic(',
#    'space optim summari',
#    'origin in2 http://myweb2.search.yahoo.com',
#    'best assess term',
#    'queri canon',
#    'mani other attempt',
#    'signific privaci concern',
#    'such compound',
#    'boom popular',
#    'googl 0.51',
#    'engin log',
#    'acknowledg',
#    'chirita@l3s.d',
#    'bm25 weight',
#    'carpineto',
#    'extract',
#    'ndcg improv'],
#   ['news event detect',
#    'inqueri retriev',
#    'stori represent preprocess',
#    'track',
#    'multipl stream',
#    'invers event frequenc',
#    'http://opennlp.sourceforge.net/',
#    'simpl semant',
#    'idf',
#    'task definit',
#    'previou stori',
#    'import inform',
#    'cluster granular',
#    'low document frequenc',
#    'alarm rate',
#    'new ned procedur',
#    'person date organ',
#    'beij',
#    '4)natur disast',
#    'po',
#    'fireman'],
#   ['web queri classif',
#    'http://www.rankstat.com/html/en/seo-news1-most-peopleuse-2-word-phrases-in-search-engines.html',
#    'poor ad match',
#    'subject descriptor',
#    'result precis',
#    'index coloss',
#    '3.5.2 aggreg',
#    'engin context',
#    'b. interestingli',
#    'shortcom',
#    'unlabel train',
#    'higher qualiti document',
#    'idf term',
#    'kdd cup-2005'],
#   ['web search interact',
#    'level relev',
#    'advanc user group',
#    'domain expertis',
#    'advanc syntax increas',
#    'queri stream yield',
#    'dimens queri attribut',
#    'use way',
#    'term weight',
#    'main find',
#    'engin system',
#    'window identifi',
#    'page view',
#    'singl highlyrelev document'],
#   ['term relev feedback',
#    'initi queri',
#    'present list',
#    'larg cluster number',
#    'key subtask',
#    'explor plugin',
#    'rescu driver chamonix',
#    'model framework',
#    'binari judgment',
#    'link kong',
#    'tan',
#    'document" full text'],
#   ['best retriev function',
#    'support vector machin',
#    'mean averag precis',
#    'web track submiss',
#    'rocarea score',
#    '5.2.1 altern svmacc',
#    'stopword',
#    'map error',
#    'linear multivari loss',
#    'sort list',
#    'comput cost',
#    'tfidf',
#    'cosin similar',
#    'finley cornel',
#    'intern acm'],
#   ['relev feedback method',
#    'origin queri mode',
#    'origin strong baselin',
#    'languag model varianc',
#    'case averag precis',
#    'robust pseudo',
#    '20(3):259',
#    'document side',
#    'prior probabl',
#    'term candid',
#    'sampl mix',
#    'trec genom',
#    'user" inform'],
#   ['queri context',
#    'user search histori',
#    'user" intent',
#    'singl user profil',
#    'word sens discrimin',
#    'term feedback',
#    'associ rule mine',
#    'use',
#    'domain model specifi',
#    'sever trec collect',
#    'tradit ir approach',
#    'topic titl',
#    'entfin',
#    'recherch d"inform',
#    'global document',
#    'space requir',
#    'situat definit',
#    'basic languag',
#    'odp metadata',
#    'depend relat',
#    'jäverlin',
#    'pointwis mutual inform'],
#   ['model queri expans',
#    'intuit tf.idf',
#    'trec topic',
#    'side semant depend',
#    'suggest modul',
#    'pseudonam descript',
#    'bigram relev',
#    'meaning concept',
#    'inform process system',
#    'term qi',
#    'markov random field',
#    'rank function',
#    'discrimin power',
#    'acknowledg',
#    'japanes languag web',
#    'document length',
#    'support vector method'],
#   ['poisson retriev model',
#    'queri gener languag',
#    'multinomi queri',
#    'naiv bay text',
#    'mani paramet',
#    'score method',
#    'nigam',
#    'differ document length',
#    'background languag',
#    'maximum likelihood estim',
#    'trec test',
#    'sv jm−multinomi',
#    'mixtur model',
#    'gamma prior',
#    'key differ',
#    'p(λ)p(x',
#    'subsect',
#    'common word'],
#   ['definit question answer',
#    'inform extract templat',
#    'reader" curios',
#    'interest model',
#    'nugget type',
#    'import criteria',
#    'aquaint retriev modul',
#    'origin offici descript',
#    'apposit',
#    'bigram languag',
#    'entiti class',
#    'topic specif centroid',
#    'abstract current approach',
#    'howdi doodi',
#    'dissimilar term" weight',
#    'differ web resourc',
#    'mmr',
#    'auto show',
#    'notabl peopl'],
#   ['rank perform',
#    'adapt boost',
#    'trec web',
#    'attent',
#    'gener error',
#    'm. wu',
#    'rarnkboost',
#    'map ndcg@1',
#    'doc # doc',
#    'helmbold',
#    'hing loss function',
#    'convex hull',
#    'msra1000',
#    'model creation',
#    'fold cross valid'],
#   ['statist spam filter',
#    'batch svm learner',
#    'onlin discrimin',
#    'words+url',
#    'larg blog host',
#    'harm content',
#    'art classif perform',
#    'cpu onsvm',
#    'vector w',
#    '10th european confer',
#    'standard onlin order',
#    'cristianini',
#    'same featur space',
#    'expens altern',
#    'train support'],
#   ['pagerank diffusionrank',
#    'web site oper',
#    'spam problem',
#    'use textual featur',
#    'trustranl−trust',
#    'manipul increas',
#    'penicillin',
#    'flow',
#    'link connect',
#    'polynomi execut time',
#    'dimens',
#    'neg heat sourc',
#    'prefer',
#    'data prepar',
#    'graph figur'],
#   ['person inform manag',
#    'task particip task',
#    'numer web',
#    'fragment recollect',
#    'acknowledg',
#    'web - bookmark',
#    'laboratori pim evalu',
#    're - use',
#    'robust descript',
#    'tool support',
#    'second diari',
#    'differ find behaviour'],
#   ['lingual queri suggest',
#    'msn search',
#    'date queri log',
#    'bid term',
#    'wuen',
#    'eqmlefcl',
#    'answer archiv',
#    'mismatch case',
#    'zhou',
#    '3.3.3 onlin mine',
#    'queri car pollut',
#    'mean',
#    'input featur'],
#   ['pagerank hit',
#    'scale hypertextu web',
#    'human evalu queri',
#    'adversari inform retriev',
#    'hyperlink environ',
#    'web spam taxonomi',
#    'effect',
#    'averag precis',
#    'queri idf valu',
#    'featur outperform',
#    'hullend',
#    'najork@microsoft.com',
#    'result map@10',
#    'bibliograph coupl',
#    'minimum score',
#    'w.r.t',
#    'uniqu',
#    'most bucket',
#    'modern hard disk',
#    'american document'],
#   ['network analysi measur',
#    'bipartit weight system',
#    'trec effect',
#    'relev judgment',
#    'topic author',
#    'system perform',
#    'search engin implement',
#    'good unhub link',
#    'indic',
#    'undirect complet graph',
#    'bibliograph citat',
#    'higher hub',
#    'scienz',
#    'hit algorithm',
#    'tabl 3a',
#    'mean averag precis',
#    'a('],
#   ['link matrix factor',
#    'complex hyperlink',
#    'semant index',
#    'pagerank citat',
#    'web document',
#    'content analysi part',
#    'mine problem',
#    'onli author inform',
#    'regular term',
#    'overal link',
#    'averag classif accuraci',
#    'same hub attribut',
#    'spam blog',
#    'homepag point',
#    'unlabel data',
#    'compact featur',
#    'mani new research'],
#   ['tempor text index',
#    'web archiv collect',
#    'document version result',
#    'travel queri',
#    'coalesc algorithm',
#    'gigabyt',
#    'new materi time',
#    'relev w(q',
#    'poor queryprocess',
#    'aol research',
#    'abov approxim guarante',
#    'content overlap',
#    'best solut',
#    'neumann gerhard',
#    'score mainten',
#    'differ dataset',
#    'weikum max'],
#   ['queri perform predict',
#    'page find task',
#    'topic retriev',
#    'descriptor',
#    'hummingbird searchserv',
#    'web environ',
#    'test collect',
#    'storag',
#    'document boundari',
#    'slqi .specif',
#    'fair comparison',
#    'term cruis',
#    'al.[7',
#    'type exist',
#    'tradit trec',
#    'jensen',
#    'cross valid'],
#   ['broad expertis retriev',
#    'find task',
#    'data fusion techniqu',
#    'spars issu',
#    'area similar tabl',
#    'avail evid',
#    'simpl multilingu model',
#    'microsoft.com/users/nickcr/w3c-summary.html',
#    'acknowledg',
#    'organiz unit',
#    'van noord',
#    'variou λ',
#    'ausweb',
#    'access databas',
#    'sourc distribut',
#    'cd document'],
#   ['contextu ad',
#    'cm market',
#    'syntact keyword match',
#    'web search index',
#    'natur extens',
#    'extract techniqu',
#    'singl metadocu',
#    'term"',
#    'lower qualiti page',
#    'requir',
#    'vector space model',
#    'v. josifovski',
#    'millisecond'],
#   ['queri expans techniqu',
#    'term document mismatch',
#    'depend languag model',
#    'ir system perform',
#    'systemat evalu',
#    'differ collect set',
#    'system more user',
#    'p.'],
#   ['retriev perform predict',
#    'uncorrel document score',
#    'spatial autocorrel',
#    'interdocu topic relationship',
#    'dimension vector',
#    'multinomi diverg',
#    'nongeneraliz',
#    'common shortcom',
#    'massachusett amherst',
#    '29th european confer',
#    'art baselin',
#    'neighbor cell',
#    'data analysi techniqu',
#    'predict power'],
#   ['increment relev feedback',
#    'natur languag process',
#    'gener tool',
#    'such redund passag',
#    'highlight',
#    'benchmark data collect',
#    'new document',
#    'annual review',
#    'major news event',
#    'tdt4 annot',
#    'nugget occurr count',
#    'autoslog',
#    'user histori h(t',
#    'engin function',
#    'distil process',
#    'kisiel languag',
#    'bootstrap approach'],
#   ['rank aggreg approach',
#    'differ irrelev document',
#    'input search',
#    'concord condit',
#    'mani sourc',
#    'differ prefer threshold',
#    'franc farah@lamsade.dauphine.fr',
#    'signific test',
#    'trec genom',
#    'method 2.2.1',
#    '| ≤',
#    '36(3):341',
#    'dj ⊆'],
#   ['vocabulari speech index',
#    'output transcript',
#    'watson research',
#    'differ word an',
#    'recal precis',
#    'video mail retriev',
#    'queri set',
#    'dynam match phone',
#    'confer room meet',
#    'lattic search',
#    'ibm haifa',
#    'prototyp asr',
#    'actual term',
#    'insert',
#    'compact represent'],
#   ['sensit queri stem',
#    'web search fuchun',
#    'languag model predict',
#    'search intent chang',
#    'term import',
#    'word run',
#    'spars data',
#    'handl case',
#    'web frequenc',
#    'differ variant',
#    'cosin similar',
#    'cooki jar',
#    'zipf" law'],
#   ['conceptu retriev system',
#    'highwir biomed journal',
#    'citat',
#    'other domain',
#    'extract',
#    'inform deci',
#    'name gene symbol',
#    'encephalopathy"[text word',
#    'aerob plate',
#    'document map imprvd',
#    'role"[mesh',
#    'definit',
#    'deterior perform'],
#   ['probabilist retriev model',
#    'averag inform',
#    'actual term frequenc',
#    'idf definit',
#    'document dimens',
#    'concept',
#    'languag engin',
#    'address entropi',
#    'dimension poisson nois',
#    'homogen collect',
#    'withindocu',
#    'pareto distribut',
#    'w1 λ',
#    'probabl p. p(k',
#    'surpris',
#    'theoric measur',
#    'negat event'],
#   ['web advertis',
#    'page" content',
#    'user" browser',
#    'inform gatekeep',
#    'match strategi',
#    'vocabulari',
#    'invers document factor',
#    'cristo comput',
#    'weight vector',
#    'http://www.todobr.com.br/',
#    'mina gerai',
#    'unintrus custom',
#    'sophist imped coupl',
#    'new expans term'],
#   ['person search',
#    'languag model perspect',
#    'addit user effort',
#    'use term',
#    'eager updat',
#    'web browser',
#    'immedi result rerank',
#    'java api',
#    'implicit feedback compon',
#    'session boundari detect',
#    'interest indic',
#    'differ recal level',
#    't. joachim',
#    'major defici'],
#   ['wireless data dissemin',
#    'skew broadcast',
#    'index minor index',
#    'popular pattern',
#    'depend queri',
#    'singl locat countri',
#    'dummi node',
#    'cach user',
#    '- uniform data',
#    'global request queue',
#    'expert system applic',
#    'approach store',
#    'informat univers',
#    'exponenti scheme',
#    'stock inform',
#    'work sever disk',
#    'zip code',
#    'push'],
#   ['complex digit librari',
#    'semant domain',
#    'extens human index',
#    'learn method',
#    'exist inform',
#    'govstat project',
#    'appropri element',
#    'unlabel data',
#    'document titl',
#    'multiword term',
#    'site" user',
#    'prototyp instanti',
#    'recurs represent',
#    'shallow classificatori structur'],
#   ['photo rank',
#    'web commun',
#    'http://searchenginewatch',
#    'potenti duplic',
#    'unifi link analysi',
#    'fusion solut',
#    'vertic domain',
#    'differ forumsexcept',
#    '||a||||b||',
#    'averag score',
#    'siam journal',
#    'ma wyma@microsoft.com',
#    'mean pca space',
#    'sub list',
#    'incomplet object',
#    'more inform'],
#   ['user profil learn',
#    'bayesian framework',
#    'movielen data',
#    'document filter',
#    'model paramet',
#    'amazon',
#    'hierarch tree',
#    'rental custom relev',
#    'unobserv latent',
#    'w999900,k',
#    'mani ir problem',
#    'b. croft',
#    'maximum entropi',
#    'depend',
#    'detail discuss'],
#   ['effect retriev algorithm',
#    'vl resourc',
#    'central logist model',
#    'languag technolog inst',
#    'merg document result',
#    'academ publish',
#    'name trec',
#    'util function',
#    'govern data',
#    'rdoc sdbdb',
#    'redd uum',
#    'lemur toolkit',
#    'skew databas size'],
#   ['document titl extract',
#    'web search',
#    'brochur',
#    'comput linguist',
#    'domain adapt',
#    'gener descript',
#    'metadata dublin',
#    'more powerpoint',
#    'mani differ file',
#    'anchor text',
#    'model precis recal',
#    'condit random field',
#    'differ rank function',
#    'a. automat',
#    'bm25 extens',
#    'preposit phrase attach',
#    'binari featur',
#    'document type sign'],
#   ['accuraci pagerank',
#    'order web',
#    'hyperlink environ',
#    'domain count',
#    'document comput symposium',
#    'featur categori',
#    'querydepend',
#    'msn"',
#    'hp.com microsoft.com/windows/i',
#    'other interest way',
#    'higher pairwis',
#    'http://dc.internet.com/news/article.php/'],
#   ['retriev evalu',
#    'new task',
#    'expens comput method',
#    'bin',
#    'defens advanc research',
#    'more confid',
#    'hypothet resesarch',
#    'robust2 track',
#    's. stern',
#    'unjudg document',
#    'calibr probabl',
#    'harman'],
#   ['retriev applic',
#    'differ distanc',
#    'profil similar coeffici',
#    'video track report',
#    'visual commun',
#    'multidescriptor environ',
#    'locat',
#    'mpeg-7 standard',
#    'mesh inform',
#    'continu measur',
#    'pictur color',
#    'edg histogram',
#    'vizir',
#    'cluster_sizei',
#    'tempor dimens',
#    'ieee'],
#   ['web crawl',
#    'differ queri gener',
#    'uncoop databas',
#    'keyword disk',
#    'archiv initi',
#    'inform return',
#    'core challeng',
#    'free text input',
#    'engin coverag',
#    'gravano',
#    'closer look',
#    'term popular',
#    'p((q1 ∨',
#    'interfac'],
#   ['approxim global pagerank',
#    'larger polit domain',
#    'sitespecif local domain',
#    'ambigu search queri',
#    'select framework',
#    'search engin www.askhenry.com',
#    'node j.',
#    'findglobalpr',
#    'dangl link',
#    'www.cs.berkeley.edu',
#    'austin',
#    'most o(n'],
#   ['topic event stori',
#    'depend event thread',
#    'topic track detect',
#    'hierarch text classif',
#    'news avail today',
#    'inform search',
#    'email thread captur',
#    'use featur',
#    'own annot',
#    'cnn',
#    'complet link model',
#    'other relat work',
#    'tdt3 corpu',
#    'acknowledg',
#    'hidden markov',
#    'follow subsect',
#    'time order',
#    'valuabl comment',
#    'sigir confer',
#    'idf vector',
#    'correct granular',
#    'ieee intellig system',
#    'flat list',
#    'new thing',
#    'osama indict',
#    'world everyday',
#    'compon',
#    'user" perspect',
#    'standard task',
#    'parent algorithm',
#    'overlap cluster',
#    'few observ',
#    'similar û×ùñ´×½',
#    'distribut',
#    'plane crash',
#    'acm press',
#    'weight',
#    'pope" visit'],
#   ['user search interact',
#    'explicit human rate',
#    'predict behavior model',
#    'higher predict accuraci',
#    'averag queri recal',
#    'feedback interpret techniqu',
#    'spam behavior',
#    'result prefer',
#    'rel clickthrough frequenc',
#    'noisi web',
#    'expect page dwell',
#    'current relev',
#    'scent',
#    'isclickbelow',
#    'featur type',
#    'queryindepend model',
#    'custom browser',
#    'research brill@microsoft.com',
#    'depend inform',
#    'q10 userbehavior',
#    'document similar',
#    'winmin toolkit',
#    'usenet news articl',
#    'link'],
#   ['corpu paramet tune',
#    'increment relev feedback',
#    'filter document',
#    'trec util',
#    'track overview',
#    'onlin topic membership',
#    'lambda perform ctrk',
#    'threshold optim strategi',
#    'crossbenchmark evalu',
#    'high recal',
#    'logist regress',
#    'neg train document',
#    't11su',
#    'actual penalti ratio',
#    'subject categories)[7',
#    'rocchio prototyp',
#    'withindocu term',
#    'open challeng',
#    'standard conjug gradient',
#    'nsf',
#    'best result',
#    'unlabel test',
#    'batch',
#    'msnbc',
#    'defens advanc research',
#    'style classifi',
#    'tdt event',
#    'crosscorpu valid',
#    'apec summit meet'],
#   ['xml retriev evalu',
#    'redund content',
#    'subsect',
#    'bibliograph entri',
#    'individu element',
#    'top rank',
#    'subject descriptor',
#    'averag document length',
#    'configur index',
#    'knowledg manag',
#    'ignor overlap',
#    'tag name',
#    'static collect',
#    'node" ancestor',
#    'unreport term',
#    'sql translat',
#    'structur requir'],
#   ['cluster web search',
#    'log inform',
#    'meaning phrase',
#    'latent semant analysi',
#    'rich inform',
#    'better result organ',
#    'classifi',
#    'queri substitut',
#    'interest aspect',
#    '× idf(w',
#    'connect document',
#    'user" interest',
#    'highest cosin similar',
#    'apparel label comparison',
#    'batch',
#    'subsect',
#    'addit text content',
#    'acknowledg',
#    'differ click',
#    'process gener term',
#    'intend mean',
#    'small map',
#    'page url',
#    'differ categori interfac'],
#   ['inform retriev model',
#    'clickthrough histori data',
#    'current queri',
#    'differ implicit feedback',
#    'click summari fixint',
#    'acknowledg',
#    'document"',
#    'contextsensitiveinformationretriev',
#    'stopword remov',
#    'test collect',
#    'select menu',
#    'trec judgment',
#    'log session identif',
#    'prior sampl size',
#    'tan',
#    'averag precis perform',
#    'award number iis-0347933',
#    'user profil'],
#   ['web search evalu',
#    'noisi user feedback',
#    'rank order',
#    'net tune algorithm',
#    'page dwell',
#    'proxim inform scent',
#    'implicit featur',
#    'technic report msr',
#    'queri querynextoverlap',
#    'signific benefit',
#    'acknowledg',
#    'eugeneag@microsoft.com',
#    'user prefer'],
#   ['geograph inform retriev',
#    'search engin perform',
#    'explicit place refer',
#    'queri estádio',
#    'tag',
#    'differ ontolog',
#    'refer class ambigu',
#    'inform need',
#    'name lisbon',
#    'subject user intent',
#    'hotel',
#    'return local result',
#    'handlingqueriesin',
#    'larger collect',
#    'algorithm1(wher',
#    'rank concept',
#    'engin log',
#    'alphanumer address',
#    'web congress'],
#   ['implicit relev feedback',
#    'search session',
#    'task complex increas',
#    'irf process',
#    'advanc comput',
#    'user behavior',
#    'entri questionnair',
#    'document retent',
#    'gener term',
#    'subject"',
#    'main experi result',
#    'provide9',
#    'tradit interact metaphor',
#    'slice search"precision"(%oftotalrepsprovidedasrf',
#    'mackinlay'],
#   ['mail learn task',
#    'email sender" intent',
#    'spam filter',
#    'actual action',
#    'autom folder assign',
#    'detect perform',
#    'item sort inbox',
#    'annot oversight',
#    'token',
#    'talk announc',
#    'same featur',
#    'percentageofmessag number',
#    'accur genr classif',
#    'junk e',
#    'bin size',
#    'acm transact',
#    'bay sentenc sentenc',
#    'key import',
#    'header inform',
#    'a.m. inform breakfast',
#    'user" view'],
#   ['text classifi probabl',
#    'unnorm confid score',
#    'effect activ learn',
#    'bayesian risk model',
#    'other discrimin',
#    'sever search engin',
#    'runtim decis',
#    'sparser kernel',
#    'differ measur',
#    'intellig',
#    'level categori',
#    'highest mutual inform',
#    'laplac mle',
#    'outlier a. gauss',
#    'acknowledg',
#    'http://www.daviddlewis.com/resources/ testcollect',
#    'loss bear',
#    'mellon univers',
#    'regress framework'],
#   ['agent execut',
#    'bdi plan',
#    'spark" abort handl',
#    'task cancel paper',
#    'forward recoveri action',
#    'own deliber',
#    'abort branch',
#    'failur condit',
#    'higher prioriti',
#    'can languag',
#    'robot navig',
#    'multipl concurr sub',
#    'belief atom'],
#   ['agent increment learn',
#    'collabor concept',
#    'instanc messag',
#    'consist mainten process',
#    'method smile',
#    'sound',
#    'definit',
#    'larg data stream',
#    'ongo hypothesi h',
#    'multiplex m20'],
#   ['agent behavior',
#    'extern observ',
#    'ghost fit predict',
#    'synthet ecosystem',
#    'bee"',
#    'forward algorithm',
#    'brophi newvector',
#    'joint state space',
#    'readperson readpredict entiti',
#    'knowledg base',
#    'futur yield predict',
#    'inward characterist',
#    'initi limit repertoir',
#    'surrog',
#    'defens advanc research',
#    'time =',
#    'defin',
#    'system design',
#    'shift'],
#   ['intellig agent architectur',
#    'avail observ',
#    'collabor filter system',
#    'commun overhead',
#    'dataaugment idea',
#    'multipl search',
#    'testb environ',
#    'user" activ',
#    'critic requir',
#    'parametr tool',
#    'manag literatur'],
#   ['peer inform retriev',
#    'previou search session',
#    'autonom agent',
#    'current rout polici',
#    'averag reward',
#    'iter learn process',
#    'hierarch p2pir system',
#    'link cost',
#    'arss queri number',
#    'queue lsi store',
#    'ttl hop',
#    'session initi a0'],
#   ['cooper agent',
#    'scarc inform resourc',
#    'gradient search scheme',
#    'social overlay network',
#    'forward request',
#    'largescal dynam system',
#    'index entri',
#    'notat acquaint relat',
#    'querypropag messag',
#    'knn approach',
#    'shortest path length',
#    'ontolog concept',
#    'aegean',
#    'high interest',
#    'flood approach',
#    'new node'],
#   ['advertis agent devic',
#    'bluetooth wireless protocol',
#    'lowest success bid',
#    'game theoret approach',
#    'bluscreen display',
#    'banner',
#    'effici schedul',
#    'os',
#    'exclus access',
#    'maximum exposur',
#    '.',
#    'likelihood estim',
#    'prototyp instal',
#    'mall'],
#   ['satellit swarm problem',
#    'space autonomi',
#    'soft conflict solv',
#    'receiv agent',
#    'plan step',
#    'inform simul',
#    'asynchron request',
#    'scalabl multicast',
#    'futur constel',
#    '- formal specif',
#    'intersatellit link',
#    'global cost',
#    'icaps"03 workshop',
#    'franc catherine.tessier@onera.fr'],
#   ['simultan auction',
#    'decreas valuat distribut',
#    'most market place',
#    'complet substitut',
#    'local maximum',
#    'free dispos',
#    'entri fee',
#    'discret simul',
#    'bernoulli trial',
#    'variabl blow',
#    'nash',
#    'other hand'],
#   ['weight vote game',
#    'multiag applic',
#    'power edg',
#    'bipartit graph',
#    'differ power indic',
#    'grand coalit',
#    'agent" remov',
#    'google" pagerank',
#    'negoti',
#    'network flow domain',
#    'natur banzhaf',
#    'theoret comput',
#    'shapley valu',
#    'definit'],
#   ['market barrier',
#    'dissatisfi product relationship',
#    'mouth commun travel',
#    'synov brand',
#    'subject opinion function',
#    'habitu mechan',
#    'random network',
#    'complex model',
#    'casual word',
#    'local rule',
#    'actual referr',
#    'purchas occas',
#    'empir evid',
#    'heterogen agent',
#    'introduct defect',
#    'modul'],
#   ['share mental model',
#    'cognit aid',
#    'task increas',
#    'overview peopl',
#    'team size',
#    'commun queue',
#    'agentpair',
#    'strategi hapi',
#    'realist expect',
#    'load statu',
#    'social requir',
#    'inform type',
#    'complex group action',
#    'ai|1 ≤',
#    'assess dimens',
#    'speech recognit',
#    'partner hi"',
#    'parti perform',
#    'higher coher'],
#   ['parallel econom search',
#    'sequenti negoti',
#    'coalit format model',
#    'dm agent" decis',
#    'pairwis match',
#    'best partnership',
#    'heterogen inform',
#    'termin search',
#    'same strategi',
#    'asynchron procedur',
#    'twosid natur',
#    'intelligenceintellig',
#    'sever complementari definit',
#    'stabil',
#    'artifici synthet environ',
#    'random interact',
#    'argmaxal∈a∗ u(ai',
#    'sarn',
#    'shopbot',
#    'k+2i'],
#   ['schedul agent',
#    'consist enforc mechan',
#    'central mdp',
#    'tempor tight',
#    'robot domain',
#    'depend activ',
#    'dynam revis',
#    'solut framework',
#    'routin return',
#    'except event',
#    'separ machin',
#    'research plan',
#    'other execut statu',
#    'stn conflict',
#    'remot enabl',
#    'group qualiti',
#    'pair shortest path',
#    'speedup'],
#   ['agent social network',
#    'contractnet protocol',
#    'valid alloc',
#    'less comput time',
#    'task depend',
#    'neighbor contractor',
#    'npcomplet problem',
#    'forc algorithm',
#    'ratio rel reward',
#    'netherland yingqian.zhang@tudelft.nl',
#    'averag degre resourc',
#    'differ problem domain',
#    'random uniform scale',
#    'upper bound'],
#   ['judgment aggreg logic',
#    'irrelev altern',
#    'axiom cpj',
#    'consist requir',
#    'rule',
#    'agenda item',
#    'condorcet" vote',
#    'agent i.',
#    'nec tabl',
#    'fmaj implement major',
#    'prefer',
#    'defin',
#    'admiss profil',
#    'tautolog taut',
#    'properti nd1',
#    'succinct represent'],
#   ['singl adversari agent',
#    'bound ration agent',
#    'maxim axiom',
#    'sum encount',
# ...
#    '∧ a = a.',
#    'σ l γ a',
#    'm. p. singh',
#    '⇒ b',
#    '⊕ b.',
#    '⊥ m',
#    'm c',
#    'c c',
#    'next n1',
#    'n1 −',
#    '⇔ n1 ≥',
#    'σ a',
#    'γ δ l',
#    'σ r',
#    'δ r',
#    'δ a'],
#   ['trade sj .',
#    'player i ∈ s',
#    'player ¯t = t',
#    'other player j = i',
#    '∩ x ∩ y =',
#    'valu bi ∈ vi',
#    'v = v1 ×',
#    '= vj − vi',
#    'definit d1 ∈ d',
#    'other sk',
#    'm =',
#    '− pi',
#    'v ⇒ r.',
#    'pi ≥',
#    '⊆ a'],
#   ['r j f = 0 rj f j',
#    'σ ): ri f ∈ bf',
#    'featur f ∈ f =',
#    'citi r s c v',
#    'rate rj f',
#    'lr ∩ t =',
#    'vi f − ef',
#    'ri f ∈ b',
#    'rf = rl = rn',
#    'hu et al',
#    'r =',
#    'rv =',
#    'wr =',
#    'ws =',
#    'lc ∩ t'],
#   ['dual solut zi = pi + p t qti',
#    'm. e. j. newman',
#    'least γ profit',
#    'agent i ∈ b',
#    'valu pi + θi',
#    'bid βt = pi',
#    'babaioff et al .',
#    'yt = αt − βt',
#    'pi = βt − θi',
#    'x y y z z',
#    'pj = θj − αt',
#    'θj − pj ≤ θi',
#    'other trader t',
#    'i ∈ s ∪b',
#    'y z x w',
#    'other trader t = t',
#    'te ∈ t'],
#   ['vertex p ∈ n',
#    'hypergraph h i',
#    'p ∈ n |',
#    '∩ h2 = ∅.',
#    '| bi ∈ b',
#    'hypertre hd = t',
#    'cf .',
#    'b =',
#    'i0 =',
#    'h ∈ h',
#    'w i',
#    'h∗ =',
#    '≤ k.',
#    'e1 ='],
#   ['|z − z |x y ≤ 3δ',
#    '= p v epv',
#    '|y − y | ≤ δ',
#    'x yz − x y z',
#    'elkind et al',
#    '|t − t | ≤',
#    '|y − y |x z',
#    'b u + c w',
#    '− u − i',
#    'l. a. goldberg',
#    'least ti −',
#    'w =',
#    'iv × iu'],
#   ['i1 i2 a1 b1 a2 b1 a1 b2 a2 b2 b1 c1 b2 c1 b1 c2 b2 c2 fb',
#    'configur a1 b2 c2',
#    'configur ˜θ ∈ ψ',
#    'attribut aj ∈ ir ∩ ir',
#    's2 s1 ∗ s2 ∗ s1',
#    '≤ l(p − p',
#    'η1 = a1 b2 c1',
#    's2 ∗ s2 ∗ s1',
#    '\x10 ¨ © a',
#    'ej = gj −1'],
#   ['e ˆ xij ˜ = xij .',
#    'p1 ij = h. denot',
#    'xf ij = xij',
#    'least second1 = 2h',
#    'most opt(p)+max ˘ l',
#    'p j xij =',
#    'pij = hj p',
#    'pi j = hj xi j / m. theorem',
#    'pij = lj lj',
#    'pi j = lj}| ≤ m −',
#    'j. c. rochet',
#    'h − l)n2,1 l',
#    'h − l)np1,t l i',
#    '= hj ≥ pk +1 ij ≥'],
#   ['i. suppos j ∈ k.',
#    '≤ |s| ≤ n −',
#    'j. whenev j ∈ k',
#    '∈ b = b1',
#    'g1 = b',
#    '− a',
#    'm − a',
#    'f1 = m',
#    'si ∈ k',
#    '∈ k',
#    'γ =',
#    'such γ',
#    '˜γ =',
#    'pα −1',
#    'b2 ×'],
#   ['pj = n−1 j = m+1 cj ≤',
#    'pn−2 j = i',
#    'zi = h(i',
#    'm. j. bailey',
#    'n − j agent',
#    'n−1 j ´ −',
#    '≤ m ˆk ≥ k∗',
#    'other n − k −',
#    'n j ´ ≤',
#    'ˆk > k∗ ≥',
#    'z1 + z2 +',
#    'n − m',
#    'n = m'],
#   ['m. w. p. savelsbergh',
#    'v2 v3 v4 v5 e1 e3 e8 e2',
#    'x × y × z',
#    'a. e. roth',
#    'v2 v3 v4 v5',
#    'v2 + v3 ≥',
#    'm1 =',
#    'm2 =',
#    'l ≥',
#    '∈ t.',
#    '∈ m',
#    'ti /∈ m',
#    'xi a',
#    'l −'],
#   ['= |x | − |x|',
#    '− r = −b p r −',
#    '= y g(x',
#    'p m x ⇔ x2 x2',
#    'b a figur',
#    '= ra p r2 a',
#    'x y = q p',
#    'ca cb = x y',
#    'm = g(x',
#    '√ p(x − x',
#    'z = |x |q',
#    '= y m x2',
#    '= p m x',
#    'q − |x |'],
#   ['edg e =',
#    'b c d e f b b b b b b b',
#    '∀i ∈ o. definit',
#    '≥ |c| −',
#    '− c ∀s ∈ s.',
#    '∀s ∈ s xi ∈',
#    'edg e. • g∗',
#    'graph h −',
#    'bi − ii(',
#    '√ n √ n',
#    'al .',
#    'bi ∈',
#    'i ∈ o',
#    'xi =',
#    '∀i ∈ o.'],
#   ['≤ ntumin ≤ ntumax',
#    'u ∈ s \\t1',
#    '∈ v \\ s. recal',
#    'l. a. goldberg',
#    'minimis b = p',
#    'karlin et al',
#    '| w ∈ v \\ s',
#    't t1 t3 t2 t4',
#    'e ∈ s1 ∩ s2',
#    '+ bi ≥ xi +',
#    't4 = t ∩ w',
#    't2 = t ∩ s'],
#   ['qi ≥ k. evalu',
#    'payoff υ ω',
#    'fagin et al .',
#    'price p∗ ≤ p',
#    'x ∧ y ∧ z',
#    '− .5 = .5 −',
#    'order o ∈ o.',
#    'υ2 − υ3 =',
#    'v1 ∧ v2 ∧ w',
#    '≤ q ≤ q',
#    '¯w ∧ v3 ∧',
#    '∈ a',
#    '≡ ω',
#    'p∗ ≥',
#    '− p',
#    '∈ e',
#    'υ3 =',
#    'α1 = α2 =',
#    'α3 =',
#    'υ1 −'],
#   ['action a∗ ∈ a',
#    'v1 − q(s2',
#    's2 = t2 ∪r2',
#    'valu vs =',
#    'n − | ˆt|',
#    'pm = c δm−1',
#    'n − |t|',
#    'case γ =',
#    'v2 − q(s1',
#    'technolog t ˆt',
#    'agent i ∈ n',
#    'boolean function f = g w h',
#    '2n n √ n',
#    'pi ≤ ci δi(a−i',
#    'γ γn =',
#    'i ∈ s',
#    '∈ o'],
#   ['❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅ ❅',
#    'h0 h1r x1 r x1 ❈ ❈',
#    'γ 2d ✷ theorem',
#    'vohra r. v.',
#    'xn ∈ rd +',
#    'φ1 ≥ φ2 ≥',
#    'x ≥ y',
#    'pi −',
#    'pi |',
#    'l ∈ r+',
#    '≤ l',
#    'xi =',
#    'xj ≤ pi',
#    'xi .'],
#   ['m − uj+1 l =',
#    'm − g[n −',
#    'm − èi= èj',
#    'agent j = i',
#    'n. initi r = m −',
#    '≤ m − uj l',
#    'pj l yj l ≤',
#    '≤ m − uj',
#    'pj l m ó',
#    'i= j xj i',
#    '≤ j ≤ mi',
#    'l ≤ xj l',
#    'xi = uj i'],
#   ['r = cω/2',
#    '≥ u a curv h',
#    'x r hr = u',
#    'dr = z cω cω',
#    'dr ≤ z cω',
#    '− u − u',
#    '≤ v ≤ cω',
#    '= αe − α',
#    'uω = r cω',
#    'keyword k ∈ k',
#    'queri q ∈ q',
#    'u = u',
#    'j ∈ k',
#    'u ≤ u',
#    '≤ b'],
#   ['c − e[v1|v1 ∈',
#    'ui = vi − pi',
#    'a b b b figur',
#    'k × k −',
#    'a a a b',
#    'x0 ≤ x1 ≤',
#    'xk = yk =',
#    'blumrosen et al',
#    'b2 ≥ k. strategi',
#    'al i aj',
#    'aj i al',
#    'θ2 ∈',
#    '= θ2',
#    '∈ r'],
#   ['n. a. r. bhat',
#    'most k−1 k',
#    'player i ∈',
#    'most k−1 k k k−1 =',
#    'p =',
#    's = s',
#    'c ←',
#    'c =',
#    '= ug',
#    'ps =',
#    '− bj',
#    '≤ bj',
#    '∈ r −',
#    's2 ×',
#    '× sn',
#    '∈ θl'],
#   ['u = vj−1',
#    'vj−1 = u',
#    'v2 v3 v4 v5 v6 v7 v w figur',
#    's s t t t',
#    's3 ⊂ b(vk+1',
#    'b1 = −a0',
#    'j = j0 −',
#    '.8 ≤ w ≤',
#    's s s s',
#    'littman et al',
#    'r ≥',
#    'w ='],
#   ['j. r. kalagnanam',
#    'm. p. wellman',
#    'attribut y ⊂ x',
#    '≤ qj rj j ∈ ad',
#    'ot b ∩ ot s',
#    'q − q q π',
#    '= q ∨ π =',
#    'xh i1 = xh i2',
#    '| t ∈ ot',
#    'ri zk i ∈',
#    '= i',
#    'π − π',
#    't \\'],
#   ['other side',
#    'mani other',
#    'σ = σ1',
#    'j ∈',
#    '= b2',
#    '≤ k',
#    '| ≤ 4k',
#    '∆ = +1',
#    '+ y.',
#    'next y',
#    'y −',
#    'y = x',
#    'a. lo'],
#   ['e. j. friedman',
#    't = t. • v t i ∈',
#    'j | v t j bt j =',
#    'same strategi sk',
#    'distribut d∗ ∈ ∆k',
#    'enough money m',
#    'bt i ∈',
#    'bt i',
#    'vt ∈',
#    'v t j',
#    'bt j =',
#    'ui = p∞',
#    'n ut',
#    'δk ='],
#   ['c. a. j. hurken',
#    'world w ∈ w',
#    'q = p(γ)-i.e .',
#    'queri qi .',
#    'k. m. j. de bontridd',
#    'yi qi ρi = p w',
#    't | w ← p',
#    'r | w ∈ w',
#    'queri q ∈ q',
#    '= q × s',
#    '= ai',
#    'π .',
#    '• ui',
#    '= ui',
#    'ui =',
#    'ai ='],
#   ['c f b b bf c b c bf b f b c b c bf b f b c',
#    'c b f b f b c b c bf b f b c',
#    's. j. j. smith',
#    'b. p. de bruin',
#    '∈ θ. signal',
#    'c b b f b f b -1 -1',
#    '˜βj i = f j ˜αj',
#    'δ n w ∈ v j |',
#    'pr(ˆβ | f j',
#    'p∗ = pr(ˆβ | f j',
#    'ˆβ | fj ˜αj',
#    'c d figur',
#    '|θ| ´ ´',
#    'vk ∈ v j \\ zj',
#    'f j −i ˆβ = ˆβ',
#    'player i ∈ i.',
#    'c b c bf b f b c',
#    '˜βj −i ≥ ui ˜z',
#    '∈ v j \\ zj'],
#   ['c. h. papadimitri',
#    'vector y ∈ rm ≥0',
#    'agent j /∈ s',
#    'agent i ∈ n',
#    'j /∈n xj ≥ xi',
#    'attribut j. let s∗ = ë j',
#    '|s ∩ b| ≥ b',
#    'w × x × y',
#    'yokoo et al .',
#    '|s ∩ c| ≥',
#    'c − c −',
#    's ⊂ t',
#    '⊇ s',
#    '≥ v',
#    '• m',
#    'rn × 2n',
#    'j /∈ s',
#    'm = n'],
#   ['m. t. hajiaghayi',
#    'hajiaghayi et al',
#    'bykowski et al',
#    'm. m. bykowski',
#    'buyer i ∈ b',
#    'mani more option',
#    'p. a. hail',
#    'lk ∈',
#    '− p.',
#    'lk =',
#    'b = l',
#    'pk i',
#    '∈ t',
#    'θ∗ t',
#    'harvard busi school ajuda@hbs.edu david c. park divis',
#    'appli scienc harvard univers parkes@eecs.harvard.edu abstract bidder',
#    'appli scienc harvard univers',
#    'adam i. juda divis'],
#   ['d. m. pennock',
#    'edelman et al',
#    '= kx t = s',
#    'h. r. varian',
#    '− wt ws bt',
#    'cs = es .',
#    'ws = ws cs',
#    't = s',
#    'xt =',
#    'ws .',
#    'ws =',
#    '= k',
#    '≥ xt',
#    'e ='],
#   ['strategi t = s',
#    'n ≥ |i | ≥',
#    't. let m',
#    '|i | = i',
#    'xn = − n',
#    '− n n −',
#    'pr(|ti | ≥ δn',
#    't =',
#    '∈ e',
#    'j ∈ mn',
#    '− γ',
#    'vn \\ mn',
#    'ti =',
#    '∈ v \\',
#    'γ =',
#    'c ≥',
#    'c =',
#    'ck ≥'],
#   ['k ≤ n',
#    'γj ∈',
#    'α =',
#    'γ1 =',
#    '´ −',
#    '´ =',
#    'γs − γt',
#    '˜ e',
#    'bi −',
#    'πi ≥',
#    '− bj',
#    'bi ≥',
#    '∀j =',
#    'j = i',
#    'γi γj',
#    'r1 ≥ r2 ≥',
#    '≥ rn',
#    'k bk ≥',
#    '≥ ri',
#    '≥ rj',
#    'i ∈'],
#   ['group p n e eu bb',
#    '− nt nt',
#    'pt −',
#    'n =',
#    '− ln',
#    '* r',
#    '* p',
#    'y. hu',
#    'r2 =',
#    'mani more recommend',
#    'bernardo a. huberman hp lab palo alto',
#    'viral market ∗ jure leskovec † carnegi mellon univers pittsburgh',
#    'michigan ann arbor',
#    'recommend'],
#   ['top k user',
#    'cm = tm − bm n',
#    'τ = c − d',
#    '∈ u | ∃ ru',
#    'herlock et al',
#    'mask q1 q2 q3 p1 p2 p3 jerri r2 r3 figur',
#    'sarwar et al',
#    'γ ≈',
#    'v = nu',
#    'top k',
#    'j = ni',
#    'i| |t',
#    '= ru',
#    'j| ≤',
#    't t'],
#   ['phelp et al',
#    '− ai(bi − ai',
#    '≥ m nn ⊂',
#    'b − b',
#    'r = r1',
#    'a = a1',
#    's. next',
#    'a1 ×',
#    '∈ ai',
#    '∈ i',
#    'ri ∈ ri',
#    'j ∈ i',
#    'γθ =',
#    'r1 ×'],
#   ['queri q =',
#    's⊆m wi xi',
#    'l. h. ungar',
#    'whole bundl ab',
#    'bundl si j',
#    's ≤ qj ∀j ∈ m x s⊆m xi',
#    'most k bundl si',
#    'm −1 valu',
#    'l. m. ausubel',
#    'm = m \\ si',
#    'k = k \\',
#    'first part'],
#   ['d. m. pennock',
#    'p. a. morri',
#    '= k',
#    '% ts',
#    'empir comparison yile chen chao-hsien chu traci mullen school',
#    'unweight linear weight linear unweight logarithm weight logarithm lin−all−u lin−all−w log−all−u',
#    'inform market',
#    'predict accuraci measur absolut error quadrat score logarithm score nf',
#    'pennsylvania state univers univers park',
#    'opinion pool',
#    'predict accuraci',
#    'logop'],
#   ['lj ∈ l(s1 i',
#    'rj ∈ r−s2 i',
#    'm − m log n ≥ n',
#    'candid si l',
#    'vote 2i −',
#    'l r l r l r',
#    'candid c =',
#    'other candid c',
#    'first 4n = n −',
#    'b l1 r1 l2 r2',
#    'top l candid',
#    'candid r − si l'],
#   ['m × n game',
#    'player j =',
#    'player i ∈',
#    'u. l m r u',
#    '| |v | − |v',
#    'least /2 − δ',
#    'σ2 ×',
#    '× σn',
#    'l r u',
#    '∈ σc',
#    'σc .',
#    's2 c.'],
#   ['s→a − sg a→b',
#    'feigenbaum et al .',
#    'v cg mechan',
#    '− n n1 n1 +',
#    '− c ≥ e[ss→a −',
#    '− c ≥ e[s|ab',
#    '− c ≥ sb',
#    's→a − sb',
#    'x r ir(b|i',
#    '− x r ir(b)br',
#    'ai ∈',
#    '− s',
#    's = pn',
#    'sg i',
#    'aj >',
#    'm =',
#    'n =',
#    'f = n'],
#   ['u = pn j=1 wj xj xj',
#    'w1 y1 ≥ w2 y2 ≥',
#    '− α m1 m2 u1',
#    'y2 j = wj',
#    '≤ j ≤ k',
#    'ri =',
#    'yj =',
#    'xi =',
#    '≤ m',
#    '≤ m.',
#    'j \uf6be',
#    's = x',
#    'x = y',
#    'm1 m2 u1'],
#   ['goldberg et al',
#    '= ⎧ ⎪⎨ ⎪⎩',
#    'β ≥',
#    'ti = bi',
#    '= bi',
#    '≥ cz',
#    'bj =',
#    '∈ s.',
#    't ≤',
#    'r ≤'],
#   ['n variabl x =',
#    'sandholm et al .',
#    'm =',
#    'b =',
#    'pj ≥',
#    'xj ∈',
#    'c =',
#    'most β',
#    'v =',
#    'xj ≥',
#    'xj ∈ r.',
#    'ed ng',
#    'x3 ≤',
#    'ireland a.holland@4c.ucc.i barri o"sullivan cork constraint comput centr depart',
#    'comput scienc univers colleg cork'],
#   ['kearn et al .',
#    'group t ⊃ s',
#    'n \\ xroot',
#    'node j. therefor',
#    'c. h. papadimitri',
#    '∀i ∈ n λs ≥',
#    'xi = xj = xk',
#    '← xj \\ xi',
#    '← xi \\ xj',
#    'u ∩ xroot = ∅.',
#    'p1 ∧ p2 ∧',
#    '• n',
#    'x ∈ rn',
#    '1s ∈ rn'],
#   ['lehmann et al .',
#    'game g1 = g',
#    'agent j =',
#    '◦ f satisfi mp',
#    'archer et al .',
#    'tr+1 = tr s sj',
#    'hk ≥ fk(c|i di',
#    'set tr+1 = tr s sj',
#    'o ◦ f)i(c|i di',
#    '≤ r ≤ t. therefor',
#    'cr i1 ≤ cr i2',
#    'r = r s j.',
#    'output o ◦ f',
#    'si ⊆ si'],
#   ['θi pi ≥ θj pj ≥ θk pk',
#    'li − lj = rj − ri =',
#    'job i. thu',
#    'n. defin q =',
#    'pj − pi j > i',
#    'θn j < n pj pi',
#    '− t s ∆(t',
#    'θi pi ≥ θj pj',
#    'j ∈ s(γ',
#    'job n \\',
#    '∀ j ∈ k.',
#    '¡ li − lj',
#    'ti − tn pi',
#    'j = k pj',
#    'pi j = θj'],
#   ['lt b ≤ l. proposit',
#    'βp = |c| p',
#    'lt b ≤ lt a.',
#    'vt a + vb',
#    '− p 2p −',
#    't ≤ lt b.',
#    'hb − lb −',
#    'la = la',
#    'la −',
#    'least −t',
#    'βp ≥ l',
#    'si .',
#    'p ≤',
#    'ph ∈'],
#   ['park et al',
#    'd. c. park',
#    'cramton et al',
#    '-b -5 seller',
#    'trade λ =',
#    'pp − po pp',
#    'p∗ j ≥ pj',
#    'λ ∈ feas(x0',
#    'v ∗ − v−i',
#    'x1 = x0',
#    'pp ≥ po',
#    'x0 =',
#    'x0 i ='],
#   ['y z u p figur',
#    '∈ lcv w bc',
#    'da db dc dd de v w',
#    'db ∩ dc ∩ vw = ib',
#    '× db × dc ∩ t3',
#    'ui ∈ dai',
#    'uk = v = u0',
#    'l2 = l − l1',
#    '× dc −→ r',
#    '= w ∈ db',
#    's = ∅. s',
#    '≤ j ≤ t',
#    '∈ db × dc',
#    '= a1 = b'],
#   ['− li ≥ vj(k',
#    'v ∗ − vj(i',
#    'alloc t ∗',
#    'li − ci ≥',
#    'least li − ci',
#    '∗ = hj .',
#    'π = n',
#    'ti ∈',
#    't =',
#    'n ∩ m',
#    '= −1',
#    '≤ l',
#    '≤ h',
#    '− l',
#    '− h.'],
#   ['i. p. l. png',
#    'ut = t τ = t',
#    'γ ve',
#    '− cd t',
#    'cd t .1',
#    'same amount',
#    'mani other',
#    'δt ut',
#    'β t',
#    'δτ uτ',
#    'β ∈',
#    'other side',
#    '− pd',
#    '− x',
#    'β =',
#    'immedi gratif alessandro acquisti h. john heinz iii school'],
#   ['m chariti c1',
#    '2|v | −',
#    'much bidder j',
#    '≤ j ≤ n',
#    'ui j ≤ tl',
#    '∈ k',
#    'b0 =',
#    'li k',
#    'other v',
#    't −',
#    'ui j.',
#    'ui j =',
#    'most h.',
#    '2h − c',
#    'xi ≤',
#    'rj i',
#    '− sj',
#    '≤ h',
#    '= u1'],
#   ['tclose f − ts c ≤ lc ≤ vc',
#    'ˆdi ≥ ˆli = ⇒ ei',
#    '≥ li proof',
#    'i ∈ avail',
#    '∀ ˆli ≥ li',
#    'v1 ≥ √ k',
#    '+ lf = df',
#    '− t − li',
#    'df = df +',
#    '+ δ = k',
#    'time t ∈',
#    'least li',
#    'vi li',
#    'θ1 ×',
#    '∈ o',
#    'ri ≤ t.',
#    'k ≥',
#    'te ='],
#   ['much player a',
#    'ratio r = ps',
#    'sc st',
#    'sc pp',
#    'sc ts',
#    'ps ≥ ss',
#    'p = .3',
#    'k = ps',
#    'cs =',
#    'ps =',
#    'cs ∗ r',
#    'k =',
#    'j. r.',
#    's. a',
#    'd. k.',
#    's. d.',
#    'm. t.',
#    'ed .',
#    'd. s. h.',
#    'm. a.',
#    'm. k.',
#    'p. k.',
#    'c. j.'],
#   ['δ/2 − rδ',
#    'ab − zi ab ≤ zi',
#    '− 2r ≥ 2q',
#    'a b ab a',
#    'ab − zi a',
#    '− q − r',
#    'zb − zb',
#    'g − s',
#    'ω. moreov',
#    'st s',
#    'z ×',
#    '|x −',
#    '∈ z',
#    'q ≤ 2r',
#    '− 2r',
#    'other side'],
#   ['θ1 ×',
#    'θi × o',
#    'g =',
#    'o. •',
#    '× θi ×',
#    'least g',
#    '= −1',
#    '∈ l',
#    'n. throughout',
#    'most nt',
#    '∈ o',
#    'o = o0',
#    '∈ θ1 × θ2 ×',
#    'θ =',
#    'l =',
#    '+ v',
#    'l /∈ c'],
#   ['c m = m1 h e n n2 −',
#    'p1 = m2 n1 p2 = m1 n2',
#    'm2 n1 = t n1 p2 = m1',
#    'p1 = m1 √ n1 m2 √ n2',
#    'm2 m1+m n2 dn dm = n1',
#    'm2 m1+m n2 m1',
#    '= m1 √ n1 m1 √ n1',
#    'm2 n1 = m1 √ n1n2',
#    '= m1 n2 e n n2',
#    'p1 = p2 p2 = p1',
#    'm2n2 = m1',
#    'm2 ln » t(m1',
#    '= p1 e[p1|a',
#    'n2 −2 r n1 n2',
#    '+ c m = m1',
#    '√ n2 z dm m1',
#    'm2 n2 = t n2',
#    'm1 m2 = p1 p2 =',
#    '= m1 √ n1 m2 √ n2 mpr(a',
#    'm n2 dm m1',
#    'n2 −2 r n1',
#    'z dn √ n1',
#    'p1 = p2 dm',
#    'm2 n1 mpr(b',
#    'p j',
#    'few other',
#    'p1 e',
#    '= p1 p1',
#    '= p1',
#    'p2 p1',
#    '= r',
#    '= z',
#    'p1 p2'],
#   ['agent i ∈ n',
#    'padget et al .',
#    'function ˜f ∈ c',
#    'bundl s ⊆ m',
#    'blum et al .',
#    'd. c. park',
#    'b ∈b | b ⊆b',
#    'b∈ ˜b | b⊆',
#    '∈ x.',
#    '˜f = f',
#    'n =',
#    'si ∩ sj',
#    'j ∈ n.',
#    '∈ γ',
#    '− p.',
#    '∈ c',
#    'p = np',
#    '∈ v1 ×',
#    '× vn',
#    's ⊆ m',
#    '∈ n'],
#   ['most √ rpmin',
#    'top n price pi',
#    'sequenc s ∈ σ',
#    'p1 ≥ p2 ≥',
#    'v n share',
#    'n − n',
#    'u = t',
#    't = t',
#    '= t',
#    'v = t',
#    '≡ t',
#    's s∗',
#    's ∼ a.',
#    'same amount'],
#   ['θi − f(n−1',
#    'n−1+αj n θj',
#    '− p c n−1+p c',
#    '= n n−1+αj x.',
#    '− pc n −',
#    'θi = n −',
#    '= θi − pc',
#    'agent j =',
#    '= f',
#    'θ =',
#    'pc − pc',
#    'pc θi −',
#    'θi ='],
#   ['epg g2 =',
#    'sink t = t2',
#    'path qi ∈ σi',
#    'sourc s. let t∗ e',
#    'edg e ∈ b',
#    'graph g =',
#    'other edg e ∈ b',
#    'c d e f h g b figur',
#    'g = g1||g2',
#    't∗ e1 ∩ t∗ e2',
#    'player i ∈',
#    'player k. t2',
#    'player j ∈ γ ∩ t2',
#    'game λ =',
#    'σ = σ1 ×',
#    't2 t1 s1 s2',
#    '≤ k ≤ n.',
#    'player γ ⊂ n',
#    'i ∈ γ',
#    'first one',
#    'n =',
#    '× σn',
#    '∈ e'],
#   ['c. l. gile',
#    'r. d. mckelvey',
#    'l. t. nielsen',
#    'price p∞ =',
#    'same price p∞',
#    '= e(f|x ∈ s∞',
#    'nielsen et al',
#    'b1 a1 = p(c2(x1',
#    'd. m. pennock',
#    '= x1 ⊕ x2',
#    'sr ⊆ sr−1',
#    's∞ = sr−1',
#    'j+ = j−',
#    'j− = j+',
#    'n − k',
#    'amount bi',
#    '/ n.',
#    '∈ s0',
#    'x. thu',
#    's1 =',
#    '= p1',
#    'sr i =',
#    'x2 =',
#    'j+ =',
#    '): xi =',
#    'y ∈ s∞',
#    'p∞ j+',
#    '− p∞',
#    '− j+ i']]}

# %%
import pickle

with open('outputs_semeval2010.pkl', 'wb') as f:
    pickle.dump(outputs, f)

# %%
import pickle

with open('outputs_semeval2010.pkl', 'rb') as f:
    outputs = pickle.load(f)

# %% [markdown]
# Оценка моделей F1-метрикой

# %%
def evaluation(predictions, references):
    precision = len(set(predictions) & set(references)) / len(set(predictions))
    recall = len(set(predictions) & set(references)) / len(set(references))
    F1_metrics = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0
    return F1_metrics

# %% [markdown]
# Плохой результат из-за недостаточной обработки текста

# %%
import numpy as np
evals = {}
for model in outputs:
    scores = []
    for output, reference in zip(outputs[model], references):
        scores.append(evaluation(output, reference))
    avg_score = np.mean(scores, axis = 0)
    evals[model] = round(avg_score, 2)
evals
# Out:
# {'KeyBERT': np.float64(0.03),
#  'Rake': np.float64(0.01),
#  'TextRank': np.float64(0.02),
#  'TopicRank': np.float64(0.13),
#  'YAKE': np.float64(0.02)}

# %%
outputs['YAKE'][233]
# Out:
# ['tclose f − ts c ≤ lc ≤ vc',
#  'ˆdi ≥ ˆli = ⇒ ei',
#  '≥ li proof',
#  'i ∈ avail',
#  '∀ ˆli ≥ li',
#  'v1 ≥ √ k',
#  '+ lf = df',
#  '− t − li',
#  'df = df +',
#  '+ δ = k',
#  'time t ∈',
#  'least li',
#  'vi li',
#  'θ1 ×',
#  '∈ o',
#  'ri ≤ t.',
#  'k ≥',
#  'te =']
